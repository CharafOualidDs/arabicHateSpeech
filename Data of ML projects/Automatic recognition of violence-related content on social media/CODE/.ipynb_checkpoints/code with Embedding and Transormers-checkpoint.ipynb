# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import emoji
from camel_tools.tokenizers.word import simple_word_tokenize
from sentence_transformers import SentenceTransformer
from gensim.models import Word2Vec
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import SVC
from imblearn.over_sampling import RandomOverSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve, auc
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import tensorflow as tf
import re
import string
import nltk
import emoji
import torch

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve, roc_curve, auc
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_curve, auc


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

from camel_tools.tokenizers.word import simple_word_tokenize
from sentence_transformers import SentenceTransformer
from gensim.models import Word2Vec
from imblearn.over_sampling import RandomOverSampler
from transformers import AutoTokenizer, AutoModel

# %%
# Charger le fichier CSV
df = pd.read_csv('cleaned_final_data.csv')

# %%
# Afficher les premières lignes du DataFrame
print(df.head())

# Afficher des statistiques descriptives du DataFrame
print(df.describe())
# Out:
#                                                 Text  Toxic/Not Toxic
# 0  يبغي التنبيه على ان السعودية تستخدم صواريخ جو ...                1
# 1  مريكا قتلت بالامس معوق رفض رفع يديه فماذا تريد...                1
# 2  هذا الشخص هو من كان يد لاحتلال العراق وضرب افغ...                1
# 3  الى جمال ريان مذيع الجزيرة نحن من رعاك فى المه...                1
# 4  خيبة ال مل ليست تشا ما ولا تقولا عزم لكفالة ال...                0
#        Toxic/Not Toxic
# count     77176.000000
# mean          0.561211
# std           0.496242
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000

# %% [markdown]
# <h1>Embedding

# %%
df['Text'] = df['Text'].fillna('')

sentences = [text.split() for text in df['Text']]
embedding_model = Word2Vec(sentences, vector_size=100, window=5, min_count=1)

# %%
embedding_model.wv.save("word_vectors.wv")

# %%
sentences
# Out:
# [['يبغي',
#   'التنبيه',
#   'على',
#   'ان',
#   'السعودية',
#   'تستخدم',
#   'صواريخ',
#   'جو',
#   'ارض',
#   'مزودة',
#   'بتقنيات',
#   'بوليس',
#   'النهي',
#   'عن',
#   'المنكر',
#   'في',
#   'الجلد',
#   'في',
#   'الساحات',
#   'المعروفة',
#   'بدقتها',
#   'المطلقة',
#   'في',
#   'اليمن'],
#  ['مريكا',
#   'قتلت',
#   'بالامس',
#   'معوق',
#   'رفض',
#   'رفع',
#   'يديه',
#   'فماذا',
#   'تريد',
#   'من',
#   'الشرطة',
#   'المصرية',
#   'تفعل',
#   'عندما',
#   'تعامل',
#   'مع',
#   'مسلحين',
#   'معهم',
#   'متفجرات'],
#  ['هذا',
#   'الشخص',
#   'هو',
#   'من',
#   'كان',
#   'يد',
#   'لاحتلال',
#   'العراق',
#   'وضرب',
#   'افغانستان',
#   'ومحارب',
#   'لاسلام',
#   'ولست',
#   'متوقع',
#   'ان',
#   'قناة',
#   'الجزيرة',
#   'تنزل',
#   'لهذا',
#   'المستوى'],
#  ['الى',
#   'جمال',
#   'ريان',
#   'مذيع',
#   'الجزيرة',
#   'نحن',
#   'من',
#   'رعاك',
#   'فى',
#   'المهد',
#   'واطعمناك',
#   'من',
#   'خيرنا',
#   'وعلمناك',
#   'من',
#   'علمنا',
#   'ولما',
#   'اشتد',
#   'عودك',
#   'خونتنا',
#   'وبعت',
#   'ارضك',
#   'وقضيتك',
#   'حقدا',
#   'على',
#   'مصر'],
#  ['خيبة',
#   'ال',
#   'مل',
#   'ليست',
#   'تشا',
#   'ما',
#   'ولا',
#   'تقولا',
#   'عزم',
#   'لكفالة',
#   'اليتيم',
#   'ولو',
#   'بالعشرين',
#   'بيه',
#   'ـه'],
#  ['سفينة', 'ال', 'كاذيب', 'والنفاق', 'والفاسد', 'والاستبداد'],
#  ['لست',
#   'دري',
#   'من',
#   'هو',
#   'الذي',
#   'ستنطفى',
#   'شمعته',
#   'وتحرق',
#   'من',
#   'دخل',
#   'في',
#   'العبة',
#   'المغشوشة',
#   'من',
#   'بنفسه',
#   'عن',
#   'قذارة',
#   'وساخ',
#   'القرون'],
#  ['جمال',
#   'خاشقجي',
#   'البرالي',
#   'العلماني',
#   'يتحول',
#   'من',
#   'داعيه',
#   'عهر',
#   'ودياثه',
#   'الى',
#   'الدعوه',
#   'لجهاد',
#   'تاب',
#   'ادعوا',
#   'له',
#   'بالثبات',
#   'نصر',
#   'اله',
#   'بك',
#   'المجاهدين'],
#  ['طرف',
#   'ثالث',
#   'محايد',
#   'مثل',
#   'من',
#   'الام',
#   'المتحده',
#   'دو',
#   'المسلمين',
#   'واداه',
#   'الاستعمال',
#   'الاولى',
#   'ام',
#   'اوردوغان',
#   'الدجال',
#   'الذي',
#   'يحاصر',
#   'المسلمين',
#   'ويسمح',
#   'لاستعمار',
#   'الكافر',
#   'بقصفهم',
#   'من',
#   'اراضيه'],
#  ['عجيب',
#   'لقد',
#   'اصبحت',
#   'تعريف',
#   'كلمة',
#   'الارهاب',
#   'بما',
#   'يخص',
#   'بها',
#   'المسلمين',
#   'حتي',
#   'علموها',
#   'هذه',
#   'الكلمة',
#   'علي',
#   'قناة',
#   'الجزيرة',
#   'بدليل',
#   'هذا',
#   'التقرير'],
#  ['تبع', 'ايران'],
#  ['ليس', 'هناك', 'حشد', 'شعبي', 'نما', 'هو', 'حقد', 'شيعي', 'على', 'السنة'],
#  ['هل',
#   'ورثة',
#   'قناة',
#   'الجزيرة',
#   'القضية',
#   'الفلسطينية',
#   'من',
#   'وسا',
#   'اعلام',
#   'عربية',
#   'اكثر',
#   'من',
#   'سنة',
#   'وهم',
#   'يتاجرون',
#   'بالقضية',
#   'الفلسطينية'],
#  ['الا',
#   'لا',
#   'تشعرون',
#   'ان',
#   'النكبة',
#   'هى',
#   'نكبتنا',
#   'بداخلناوبكل',
#   'دولةعربيةفلم',
#   'تحتل',
#   'الا',
#   'اسرا',
#   'يل',
#   'فلسطين',
#   'فهى',
#   'كذبة',
#   'كبيرة',
#   'بل',
#   'الاستعمار',
#   'احتلنا',
#   'كلناونصب',
#   'اسرا',
#   'يل',
#   'على',
#   'كل',
#   'ارض',
#   'عربية',
#   'وكونوا',
#   'اسرا',
#   'يل',
#   'الكبرى',
#   'قبل',
#   'ما',
#   'يحتلون',
#   'فلسطين'],
#  ['وكيف', 'تكونوا', 'مقاومين', 'وافعالكم', 'كاليهوذ'],
#  ['هل', 'لو', 'كان', 'الحريري', 'هو'],
#  ['او',
#   'هذا',
#   'البرنامج',
#   'الذي',
#   'يقدمه',
#   'فيصل',
#   'القاسم',
#   'هو',
#   'برنامج',
#   'فتن',
#   'ليس',
#   'برنامج',
#   'يثير',
#   'الفتن',
#   'بين',
#   'المجتمعات',
#   'في',
#   'الدول',
#   'العربية',
#   'وهو',
#   'برنامج',
#   'في',
#   'خدمة',
#   'العدو',
#   'الصهيوني',
#   'ومن',
#   'لف',
#   'في',
#   'فلكهم'],
#  ['سيد', 'فيصل', 'حترامي', 'وتعلم'],
#  ['اتمنى',
#   'في',
#   'الحلقات',
#   'القادمة',
#   'من',
#   'الاستاذ',
#   'فيصل',
#   'ان',
#   'يقدم',
#   'حلقاته',
#   'من',
#   'داخل',
#   'قسم',
#   'البوليس',
#   'وذلك',
#   'منعا',
#   'لعدم',
#   'حصول',
#   'اي',
#   'عاه',
#   'دا',
#   'مه',
#   'لاحد',
#   'الضيوف',
#   'عندما',
#   'تشتعل',
#   'المعركة',
#   'بينهما',
#   'وحرصا',
#   'على',
#   'سلامتك',
#   'انت',
#   'ايضاستاذ',
#   'فيصل'],
#  ['هالبرنامج',
#   'صاير',
#   'مسخره',
#   'الجزيره',
#   'تلغي',
#   'هالبرنامج',
#   'المفروض',
#   'بدنا',
#   'برامج',
#   'جديده',
#   'يا',
#   'جزيره',
#   'هالاتجاه',
#   'المعاكس',
#   'لازم',
#   'يتقاعد'],
#  ['الحسين',
#   'حفيد',
#   'الرسول',
#   'عليه',
#   'الصلاة',
#   'السلام',
#   'يهودي',
#   'الدين',
#   'اسرا',
#   'يلي',
#   'القوميه',
#   'صهيوني',
#   'المعتقد',
#   'لذلك',
#   'فان',
#   'راية',
#   'لبيك',
#   'يا',
#   'حسين',
#   'اسرا',
#   'يلية',
#   'صهيونية',
#   'اليس',
#   'كذلك',
#   'تبا',
#   'لك',
#   'لكل',
#   'عقل',
#   'عفن',
#   'طا',
#   'في',
#   'مريض'],
#  ['رحمة',
#   'اله',
#   'عليكي',
#   'يا',
#   'جزيرة',
#   'كنتي',
#   'منبر',
#   'ما',
#   'لا',
#   'منير',
#   'له',
#   'واليوم',
#   'اصبحتي',
#   'تستجدي',
#   'المشاهدين',
#   'بالاثارة',
#   'الرخيصة'],
#  ['شكرا',
#   'علا',
#   'الخطيب',
#   'على',
#   'توضيحه',
#   'الحقا',
#   'المشكلة',
#   'في',
#   'الجمهور',
#   'العربي',
#   'والمتلقي',
#   'صبح',
#   'لا',
#   'يفرق',
#   'بين',
#   'الصالح',
#   'والطالح',
#   'سرمد',
#   'عبدالكريم',
#   'رجل',
#   'لا',
#   'يملك',
#   'معلومات',
#   'سوى',
#   'مجرد',
#   'ترديد',
#   'ما',
#   'يرده',
#   'ال',
#   'علام',
#   'الصهيو',
#   'مريكي',
#   'فقط'],
#  ['انت',
#   'تقول',
#   'لبيك',
#   'ياصدام',
#   'حسين',
#   'وتجد',
#   'البعثية',
#   'والدواعش',
#   'يدين',
#   'بينما',
#   'ينزعجون',
#   'من',
#   'لبيك',
#   'ياحسين'],
#  ['وكاني',
#   'ارى',
#   'ابتسامه',
#   'البغدادي',
#   'تمتد',
#   'من',
#   'الاذن',
#   'الى',
#   'الاذن'],
#  ['بل',
#   'كلامه',
#   'كله',
#   'مغالطات',
#   'وبعد',
#   'ذكر',
#   'علا',
#   'حقيقة',
#   'الرجل',
#   'ثار',
#   'غضب'],
#  ['انتم',
#   'الوهابين',
#   'السعودين',
#   'خر',
#   'من',
#   'يتكلم',
#   'عن',
#   'الجيش',
#   'الحقيقي',
#   'المعارك',
#   'خر',
#   'حرب',
#   'شاركت',
#   'فيها',
#   'كانت',
#   'في',
#   'زمن',
#   'الجاهلية',
#   'الذي',
#   'ما',
#   'زلت',
#   'تعيشون',
#   'فيه',
#   'لى',
#   'ال',
#   'ختم',
#   'الحرب',
#   'ضد',
#   'رسول',
#   'اله',
#   'صلى',
#   'اله',
#   'عليه',
#   'له',
#   'وسلم'],
#  ['والكورد',
#   'يحتاجون',
#   'لى',
#   'قرون',
#   'حتى',
#   'يتصرفون',
#   'بدون',
#   'خيانة',
#   'فخياناتهم',
#   'في',
#   'كل',
#   'دولة',
#   'على',
#   'حساب',
#   'حجمهم',
#   'فهم',
#   'خونة',
#   'دولهم',
#   'بامتياز',
#   'في',
#   'تركيا',
#   'والعراق',
#   'وسوريا'],
#  ['اذا',
#   'العرب',
#   'يحتاجون',
#   'قرنين',
#   'اذا',
#   'كم',
#   'يحتاج',
#   'الاكراد',
#   'حتى',
#   'يصبحون',
#   'بشر',
#   'اقزام',
#   'تكلم',
#   'عن',
#   'عملاقة',
#   'اول',
#   'مرة',
#   'خلي',
#   'يصير',
#   'عدكم',
#   'وطن',
#   'وبعدين',
#   'تكلم',
#   'على',
#   'الاخرين',
#   'كاكا'],
#  ['هذه',
#   'المسخره',
#   'العراقية',
#   'ترل',
#   'حقيقة',
#   'شعب',
#   'العراق',
#   'اهل',
#   'الريا',
#   'والنفاق',
#   'الضيفين',
#   'في',
#   'البرنامج',
#   'كانوا',
#   'في',
#   'قمة',
#   'الغبا',
#   'والتفاه',
#   'شكر',
#   'دكتور',
#   'فيصل',
#   'فقد',
#   'قدمت',
#   'نموذج',
#   'عربي',
#   'سي',
#   'لكي',
#   'نعرف',
#   'من',
#   'هم',
#   'العرب',
#   'ولا',
#   'تعليق',
#   'اكثر'],
#  ['ساسا',
#   'المافيات',
#   'الميليشيات',
#   'هي',
#   'دوات',
#   'مريكا',
#   'وايران',
#   'لسيطره',
#   'على',
#   'العراق',
#   'ونهب',
#   'موارده',
#   'وقتل',
#   'كوادره',
#   'بيع',
#   'وشرا',
#   'الرتب',
#   'والمناصب',
#   'مر',
#   'عادي',
#   'في',
#   'عراق',
#   'الدم',
#   'قراطيه',
#   'ما',
#   'هو',
#   'موجود',
#   'هو',
#   'سور',
#   'لحراميه',
#   'وليس',
#   'لوطن'],
#  ['جيوش',
#   'بزنيس',
#   'لا',
#   'اكثر',
#   'لا',
#   'اقل',
#   'كلها',
#   'من',
#   'المحيط',
#   'الى',
#   'الخليج'],
#  ['وكم', 'قرن', 'يحتاج', 'الكرد', 'ليصلوا', 'لمرحلة', 'الانسان'],
#  ['ياجزيره',
#   'العنوان',
#   'غلط',
#   'امريكا',
#   'هي',
#   'طرف',
#   'في',
#   'الحرب',
#   'العنوان',
#   'نها',
#   'محايده',
#   'سعود',
#   'ليس',
#   'لديهم',
#   'المقدره',
#   'لقيام',
#   'بالحرب',
#   'لولا',
#   'الدعم',
#   'الامريكي'],
#  ['هىخيارات',
#   'اليمنين',
#   'وليس',
#   'الحوثين',
#   'فقط',
#   'وجها',
#   'لعدوان',
#   'دول',
#   'الجبنا',
#   'العملا'],
#  ['بل',
#   'انه',
#   'خيار',
#   'الشعب',
#   'اليمنى',
#   'الذى',
#   'يتعرض',
#   'لاعتدا',
#   'ومن',
#   'الا',
#   'عملا',
#   'بالخليج',
#   'لا',
#   'لكم',
#   'الوجه',
#   'لتنشروه'],
#  ['جهنم',
#   'الفقر',
#   'والمتاجرة',
#   'بال',
#   'عضا',
#   'البشرية',
#   'عراض',
#   'ال',
#   'مهات',
#   'بال',
#   'كراه',
#   'ما',
#   'وزارة',
#   'لسنا',
#   'قادرين',
#   'فلا',
#   'رضع',
#   'فلذلك',
#   'كانوا',
#   'ولذلك',
#   'هم',
#   'ولا',
#   'كما',
#   'هم',
#   'ما',
#   'طيب',
#   'غيور',
#   'في',
#   'حق',
#   'وما',
#   'شقاه',
#   'ستعجال'],
#  ['هل', 'لكم', 'اكثرمن', 'عدن', 'يا', 'عملا', 'يا', 'خونة'],
#  ['ما',
#   'تقوم',
#   'به',
#   'السعودية',
#   'والامارات',
#   'من',
#   'تسليح',
#   'القاعدة',
#   'والمرتزقة',
#   'سيودي',
#   'لى',
#   'تقوية',
#   'داعش',
#   'في',
#   'اليمن'],
#  ['بماذاسيدخلون',
#   'بجنود',
#   'باكستان',
#   'يا',
#   'متاع',
#   'فتلك',
#   'الشعوب',
#   'لم',
#   'تعى',
#   'من',
#   'بعد',
#   'ما',
#   'سيخلفونه',
#   'لهم',
#   'لا',
#   'العملا',
#   'الجبنا',
#   'قبل',
#   'ما',
#   'يهربون',
#   'لنيوجيرزى',
#   'مقرهم',
#   'ويتركوهم',
#   'لمصيرهم',
#   'وتلك',
#   'هى',
#   'الشعوب',
#   'القابلة',
#   'لمحتلين',
#   'والمستعمرين',
#   'وعملا',
#   'هم'],
#  ['صباح', 'الخير'],
#  ['اسد',
#   'اكبر',
#   'مجرمين',
#   'في',
#   'الكون',
#   'العميل',
#   'حافظ',
#   'ال',
#   'سد',
#   'قال',
#   'اختار',
#   'القبر',
#   'السجن',
#   'ورا',
#   'الستار',
#   'في',
#   'موساد',
#   'عن',
#   'حمايه',
#   'عن',
#   'نفسها',
#   'وتخريب',
#   'ال',
#   'راضي',
#   'المقدسه'],
#  ['الحريري',
#   'ابنه',
#   'لوليد',
#   'المعلم',
#   'من',
#   'غير',
#   'امر',
#   'اس',
#   'لوه',
#   'بحوزته',
#   'الاسبات',
#   'والصور',
#   'هلق',
#   'بقلك',
#   'اسرا',
#   'يلى'],
#  ['قمة',
#   'المهزلة',
#   'ينحدر',
#   'مقدم',
#   'البرنامج',
#   'لى',
#   'هذا',
#   'المستوى',
#   'الضحل',
#   'بهكذا',
#   'موضوع',
#   'وهو',
#   'ابن',
#   'الطا',
#   'فة',
#   'التي',
#   'يتكلم',
#   'عنها',
#   'هذه',
#   'الفتنة',
#   'بحد',
#   'ذاتها'],
#  ['بسم',
#   'اله',
#   'الرحمن',
#   'الرحيم',
#   'الهم',
#   'خذ',
#   'عدوك',
#   'السيسي',
#   'اخذ',
#   'عزيز',
#   'مقتدر',
#   'وشت',
#   'شمل',
#   'من',
#   'يناصره'],
#  ['ريحتكم', 'طلعت'],
#  ['واضح',
#   'من',
#   'التعليق',
#   'ان',
#   'حضرتك',
#   'من',
#   'ازلام',
#   'المخابرات',
#   'وتريد',
#   'تضيع',
#   'الموضوع'],
#  ['سنفجر',
#   'متى',
#   'نشا',
#   'واينما',
#   'نريد',
#   'فموتوا',
#   'بغيظكم',
#   'ايها',
#   'الكلاب'],
#  ['روح',
#   'يا',
#   'خاين',
#   'يا',
#   'عميل',
#   'يا',
#   'نذل',
#   'والى',
#   'يتبعك',
#   'ولعملا',
#   'السعودية',
#   'والحوثين',
#   'اظهرو',
#   'انهم',
#   'اكبر',
#   'وطنية',
#   'منكم',
#   'يا',
#   'عملا',
#   'يا',
#   'خونة'],
#  ['بتمام',
#   'مكارم',
#   'خلاق',
#   'مهاتهم',
#   'وترك',
#   'الفواحش',
#   'ما',
#   'ظهر',
#   'منها',
#   'والشر',
#   'كل',
#   'الشر',
#   'ما',
#   'بطن',
#   'ما',
#   'قتل',
#   'وسرقة',
#   'لفساد',
#   'مسبق',
#   'دون',
#   'بينة',
#   'وحكم',
#   'السن',
#   'فيه',
#   'حتمية',
#   'هلاك',
#   'النسل',
#   'والزرع'],
#  ['قـارعـة',
#   'سمها',
#   'دب',
#   'ذان',
#   'لسوط',
#   'عذاب',
#   'سف',
#   'يعني',
#   'قدرة',
#   'رب',
#   'العزة',
#   'رحمة',
#   'وبطش',
#   'شديد',
#   'مبر',
#   'بظلم',
#   'وجهل',
#   'نذار',
#   'لعلهم',
#   'يرجعون',
#   'دردش',
#   'وبرمجة',
#   'ونواصي',
#   'مسخ',
#   'وجهنم'],
#  ['هذالتحليل', 'كله', 'تضليل', 'ولمقدمته'],
#  ['الثورة', 'اصدمت', 'بالصعاليك', 'وسندكهم'],
#  ['فلما', 'لكم', 'يا', 'متاسلمين', 'اتباع', 'فاخرجوهم'],
#  ['شعوبناقابلةلاستعماراخاف', 'ان', 'لاتعش', 'الابه', 'فلهذا', 'حالنا', 'هكذا'],
#  ['الم',
#   'رخ',
#   'يتحدث',
#   'وك',
#   'ليس',
#   'الاستعمار',
#   'من',
#   'يدير',
#   'عملا',
#   'ولاسلامين',
#   'لرد',
#   'الثورةوالتىهى',
#   'التحر',
#   'منهم'],
#  ['الا',
#   'عدوا',
#   'لتصريحات',
#   'بوب',
#   'كينيدى',
#   'ان',
#   'شعوبنالعربية',
#   'تعاقب',
#   'امريكا',
#   'بالثورة',
#   'على',
#   'عملا',
#   'هم',
#   'وستفهم',
#   'الكل',
#   'ولماذا',
#   'تعاقبهم',
#   'ولانها',
#   'ثارت',
#   'على',
#   'عملا',
#   'هم'],
#  ['الرجا', 'التثبت', 'لا', 'يمكن', 'قرا', 'الفيديو'],
#  ['وكلكم', 'عملا', 'لحكام', 'السعودية', 'ولاخوان'],
#  ['الشريط', 'يحتوي', 'على', 'ثانية', 'فقط'],
#  ['هذه',
#   'المنظمة',
#   'كالشيطان',
#   'عليه',
#   'من',
#   'العنه',
#   'ونعوذ',
#   'باله',
#   'من',
#   'شره',
#   'ونفحة',
#   'وهمزه',
#   'وعمزه',
#   'ترضي',
#   'بالقليل',
#   'حتي',
#   'كاد',
#   'الانقلابي',
#   'والحوثي',
#   'ان',
#   'يبتلع',
#   'اليمن',
#   'هو',
#   'لم',
#   'يكن',
#   'يدير',
#   'مفاوضات',
#   'بل',
#   'كان',
#   'يفضي',
#   'الارض',
#   'والمدن',
#   'من',
#   'الشرعبة'],
#  ['لماذا',
#   'يجب',
#   'دا',
#   'ما',
#   'ابراز',
#   'ان',
#   'الاخوان',
#   'هم',
#   'قادة',
#   'اسلامين',
#   'الاخوان',
#   'عملا',
#   'لغرب',
#   'سرقوا',
#   'الربيع',
#   'العربي',
#   'واعادوه',
#   'لديكتاتوريات',
#   'يجب',
#   'القضا',
#   'على',
#   'الاخوان',
#   'المجرمين',
#   'حتى',
#   'لانراهم',
#   'مرة',
#   'اخرى'],
#  ['الويل', 'لك', 'كل', 'الويل', 'يا', 'علماني', 'انشري', 'يا', 'الجزيرة'],
#  ['انى', 'اقصد', 'عملا', 'السعودية'],
#  ['نعم',
#   'اقصدعملا',
#   'السعوديةولو',
#   'كرهتىياجزيرة',
#   'فه',
#   'لا',
#   'راس',
#   'الصهاينة'],
#  ['موقف',
#   'مخزي',
#   'لى',
#   'بعد',
#   'الحدود',
#   'ولكن',
#   'مع',
#   'مين',
#   'النسخة',
#   'الجديدة',
#   'من',
#   'نظام',
#   'مبارك',
#   'لا',
#   'تعرف',
#   'معنى',
#   'العار',
#   'ولا',
#   'الخزي',
#   'الغريب',
#   'في',
#   'ال',
#   'مر',
#   'دول',
#   'الخليج',
#   'الداعمة',
#   'لثورة',
#   'السورية',
#   'حتى',
#   'ال',
#   'لم',
#   'تخذ',
#   'موقف'],
#  ['الصناعة',
#   'التقليدية',
#   'في',
#   'موريتانيا',
#   'لا',
#   'يمكن',
#   'تقدم',
#   'خطوة',
#   'واحدة',
#   'طال',
#   'ما',
#   'المجتمع',
#   'الموريتاني',
#   'البيظاني',
#   'يحقر',
#   'من',
#   'يعمل',
#   'بها',
#   'يعتبرهم',
#   'طبقة',
#   'دونية',
#   'يعاملهم',
#   'بكبر',
#   'تعالي'],
#  ['وطلبه',
#   'الجو',
#   'السياسي',
#   'في',
#   'فرنسا',
#   'لمانيا',
#   'ولم',
#   'يطلبه',
#   'في',
#   'السعودية',
#   'نه',
#   'يعلم',
#   'ان',
#   'الكافر',
#   'رحم',
#   'من',
#   'المنافق',
#   'وخاصة',
#   'اذا',
#   'كان',
#   'المنافق',
#   'من',
#   'ال',
#   'عراب'],
#  ['يا',
#   'فواز',
#   'جرجس',
#   'الذي',
#   'لم',
#   'من',
#   'بديانة',
#   'سلام',
#   'لا',
#   'يحق',
#   'له',
#   'يتكل',
#   'سم',
#   'الم',
#   'سلمين',
#   'فالحروب',
#   'الصليبية',
#   'والتي',
#   'لم',
#   'تي',
#   'بالخير',
#   'لبلاد',
#   'الش',
#   'ام',
#   'حيث',
#   'كانت',
#   'دما',
#   'الم',
#   'سلمين',
#   'في',
#   'القدس',
#   'لى',
#   'كب',
#   'الخيل'],
#  ['هذا', 'الحيه', 'الخبيثه', 'داعشي', 'بامتياز'],
#  ['تعليق', 'ثمل', 'ومتخم', 'بالارهاب'],
#  ['عتقد',
#   'نه',
#   'ينبغي',
#   'لنا',
#   'نطرح',
#   'الس',
#   'ال',
#   'لماذا',
#   'ليس',
#   'كل',
#   'العرب',
#   'رهابين',
#   'كيف',
#   'نهم',
#   'لا',
#   'ينفجرو'],
#  ['من',
#   'يتحمل',
#   'مس',
#   'ولية',
#   'تغذية',
#   'الا',
#   'رهاب',
#   'بالمال',
#   'السلاح',
#   'التكفيرين',
#   'هي',
#   'السعودية',
#   'تركيا',
#   'قطر',
#   'قناة',
#   'الجزيرة',
#   'بال',
#   'علام',
#   'انشر',
#   'يا',
#   'ناشر',
#   'اذا',
#   'كنت',
#   'رجل'],
#  ['انه',
#   'اعتراف',
#   'امريكىباهدا',
#   'قنبلة',
#   'نوية',
#   'وكما',
#   'كنت',
#   'اقول',
#   'هنا',
#   'بالجزيرة',
#   'وفعلا',
#   'تم',
#   'الموافقة',
#   'عليه',
#   'وروسيا'],
#  ['واله',
#   'انا',
#   'غافلين',
#   'عنهم',
#   'لازم',
#   'نعطيهم',
#   'عيديه',
#   'في',
#   'الاردن',
#   'وتونس',
#   'ومصر',
#   'ولبنان',
#   'ونستهدف',
#   'مصالحهم',
#   'في',
#   'السعوديه',
#   'والكويت',
#   'وكل',
#   'الخليج'],
#  ['ملف', 'الجو', 'معادلة', 'لخريطة', 'ملعب', 'المجاهيل', 'المعرفة'],
#  ['باب',
#   'لا',
#   'يدخله',
#   'لا',
#   'الصا',
#   'مون',
#   'ومقدموا',
#   'برامج',
#   'ضغط',
#   'دموي',
#   'عالي',
#   'جدا',
#   'ما',
#   'التيريري',
#   'فهو',
#   'مشروب',
#   'نبات',
#   'برازيلي',
#   'تراثي',
#   'يتناوله',
#   'البرتغاليون',
#   'لتهد',
#   'عصاب',
#   'لقول',
#   'سفه',
#   'طريف',
#   'جدا',
#   'على',
#   'نقط',
#   'مشتركة',
#   'غبية',
#   'جدا'],
#  ['باله', 'يا', 'الظفيري', 'ما', 'وجدت', 'تناقش', 'الا', 'مع', 'خا', 'وخا'],
#  ['فما',
#   'يوجد',
#   'ايران',
#   'احتلال',
#   'اسرا',
#   'يل',
#   'تدعىالمقاومةلتحتل',
#   'بمثلهم',
#   'شعوبنا',
#   'القابلة',
#   'لمستعمرين',
#   'والمحتلين',
#   'باسم',
#   'المقاومة',
#   'وهى',
#   'حليفة',
#   'اسرا',
#   'يل'],
#  ['فلسطين',
#   'هي',
#   'البقرة',
#   'الحلوب',
#   'حتى',
#   'بعض',
#   'المحتالين',
#   'المخبرين',
#   'هنا',
#   'في',
#   'روبا',
#   'يستخذمونها',
#   'لجمع',
#   'ال',
#   'موال',
#   'التبرعات',
#   'يران',
#   'ليست',
#   'وحدها',
#   'من',
#   'يستفيذ'],
#  ['بسم',
#   'اله',
#   'الرحمن',
#   'الرحيم',
#   'ابوحميد',
#   'المصري',
#   'ان',
#   'كنت',
#   'تنكت',
#   'فان',
#   'دمك',
#   'ثقيل',
#   'وان',
#   'كنت',
#   'جادا',
#   'فعجبى',
#   'على',
#   'الجزيرة',
#   'وعلى',
#   'المصرين',
#   'الجد'],
#  ['انت', 'ابن', 'الزنا', 'يا', 'صهيوني', 'حرب', 'هلية', 'في', 'مصر', 'انشاله'],
#  ['وليه',
#   'ما',
#   'تقولش',
#   'انه',
#   'انتم',
#   'شعب',
#   'لم',
#   'ينضج',
#   'عقله',
#   'جيدا',
#   'حتي',
#   'يكون',
#   'لديكم',
#   'دكتور',
#   'كر',
#   'يس',
#   'دوله',
#   'ولاول',
#   'مره',
#   'في',
#   'تاريخ',
#   'الامه',
#   'العربيه',
#   'انتخابات',
#   'نزيه',
#   'ولكن',
#   'الظاهر',
#   'بسطار',
#   'العسكر',
#   'له',
#   'وحشه',
#   'لامثالك'],
#  ['بشار',
#   'الاسد',
#   'لب',
#   'من',
#   'لاب',
#   'جهنم',
#   'زند',
#   'من',
#   'الزنادقه',
#   'مشر',
#   'من',
#   'المشر',
#   'نالدروز',
#   'عدوصحاه',
#   'الرسول',
#   'وقاتل',
#   'الابر',
#   'الشام',
#   'را',
#   'لجز',
#   'ره',
#   'ومراسلها',
#   'ومراسلتها'],
#  ['هم', 'يسمونه', 'عبد', 'الناصر', 'سينما', 'لسب', 'وجيه'],
#  ['يا',
#   'شباب',
#   'يا',
#   'جماعة',
#   'يا',
#   'هو',
#   'وين',
#   'الحلقة',
#   'صار',
#   'مرة',
#   'على',
#   'مدار',
#   'ايام',
#   'عم',
#   'ندخل',
#   'ومافي',
#   'شي',
#   'غير',
#   'التقرير'],
#  ['كلو', 'بيجي', 'وقته'],
#  ['هذا',
#   'موقع',
#   'الخنزيرة',
#   'وليس',
#   'الجزيرة',
#   'فماذانتوقع',
#   'من',
#   'الخنزيرة'],
#  ['هذا',
#   'ما',
#   'كل',
#   'الجزيرة',
#   'دماغنا',
#   'به',
#   'وتلهي',
#   'الامة',
#   'به',
#   'المظاهرات',
#   'في',
#   'العراق',
#   'المظاهرات',
#   'في',
#   'العراق',
#   'المظاهرات',
#   'في',
#   'العراق',
#   'مع',
#   'انها',
#   'ليست',
#   'لها',
#   'قيمة',
#   'ولن',
#   'تقدم',
#   'ولن',
#   'خر'],
#  ['والسنة',
#   'الخونة',
#   'ينظمون',
#   'لصحوات',
#   'ويدعمون',
#   'التوسع',
#   'الصفوي',
#   'الايراني',
#   'فما',
#   'هذا',
#   'الغبا',
#   'والسذاجة'],
#  ['العبادي',
#   'مجرد',
#   'موظف',
#   'صغير',
#   'لدى',
#   'سادته',
#   'الفرس',
#   'لا',
#   'قيمة',
#   'له',
#   'صدقوني',
#   'هو',
#   'فقط',
#   'يتلقى',
#   'ال',
#   'وامر',
#   'من',
#   'طهران',
#   'ينفذ'],
#  ['فلتنظم',
#   'النخيب',
#   'وحتى',
#   'الخبيث',
#   'فحدود',
#   'السعودية',
#   'تضم',
#   'دول',
#   'المحيط',
#   'من',
#   'المغرب',
#   'لى',
#   'مصر',
#   'ومن',
#   'البحرين',
#   'لى',
#   'مكة',
#   'المكرمة',
#   'مساس',
#   'بحبة',
#   'رمل',
#   'من',
#   'ال',
#   'رض',
#   'المقدسة',
#   'سيكون',
#   'هلاك',
#   'العدو',
#   'وتحرير',
#   'البقع',
#   'المحتلة',
#   'منه',
#   'قضي',
#   'ال',
#   'مر'],
#  ['ان', 'شا', 'له', 'الزحف', 'قادم', 'حتى', 'الوصول', 'لرياض'],
#  ['تصرفات',
#   'تالشيعه',
#   'دا',
#   'ما',
#   'هي',
#   'ستفزاز',
#   'هل',
#   'السنه',
#   'كل',
#   'شي',
#   'في',
#   'عتقاداتهم',
#   'مبني',
#   'يغيظ',
#   'السنه',
#   'ويخالفهم',
#   'الر',
#   'والعم',
#   'حتى',
#   'لو',
#   'كام',
#   'مدمر',
#   'يقوموا',
#   'بعمله',
#   'منهم',
#   'له',
#   'وبا',
#   'اله',
#   'يريحنا',
#   'منهم',
#   'على',
#   'خير'],
#  ['هل',
#   'تظنون',
#   'ان',
#   'شعب',
#   'اليمن',
#   'سيتبنى',
#   'حكم',
#   'العملا',
#   'الذين',
#   'دمروا',
#   'الامة',
#   'ولكن',
#   'جاى',
#   'دوركم',
#   'ولشعوبكم',
#   'يا',
#   'بغاة'],
#  ['كاني',
#   'بقوات',
#   'قطر',
#   'تسد',
#   'انوفها',
#   'من',
#   'عفن',
#   'الم',
#   'امرات',
#   'والارتزاق',
#   'الرخيص',
#   'والجرا',
#   'المخزيه',
#   'التي',
#   'ترتكبها',
#   'السعوديه',
#   'والامارات',
#   'والاجرا'],
#  ['اتضنون',
#   'ستحسم',
#   'لصالح',
#   'العملا',
#   'الذين',
#   'دمروا',
#   'الامة',
#   'واجب',
#   'محاكمتهم',
#   'والاقتصاص',
#   'منهم',
#   'ولو',
#   'حماهم',
#   'الاستعمار',
#   'وليهم',
#   'فلم',
#   'تظحىامتنا',
#   'وتظحى',
#   'لتات',
#   'بعملا',
#   'فلن',
#   'تغلطون',
#   'ابدا',
#   'ولو',
#   'شنتم',
#   'حربا',
#   'كل',
#   'الدهر'],
#  ['تستطيع',
#   'السعودية',
#   'ودول',
#   'الخليج',
#   'شرا',
#   'كل',
#   'بال',
#   'موال',
#   'ستثنا',
#   'النصر',
#   'في',
#   'الحروب',
#   'رغم',
#   'تقنية',
#   'سلاحهم',
#   'العالية',
#   'النصر',
#   'لا',
#   'يشترى',
#   'بل',
#   'يصنعه',
#   'لرجال',
#   'الشجعان',
#   'ال',
#   'قويا',
#   'وهم',
#   'هل',
#   'اليمن',
#   'لا',
#   'غير'],
#  ['كلا',
#   'سيهزمون',
#   'ويولون',
#   'الدبر',
#   'التحالف',
#   'العربي',
#   'لا',
#   'يكون',
#   'على',
#   'اسرا',
#   'يل',
#   'ابدا',
#   'بل',
#   'ضد',
#   'اخوانهم',
#   'المسلمين',
#   'حتى',
#   'في',
#   'الشهر',
#   'الحرام'],
#  ['الظاهر',
#   'ان',
#   'حسين',
#   'الشبكشي',
#   'غير',
#   'واثق',
#   'من',
#   'صدق',
#   'نية',
#   'الجيش',
#   'ال',
#   'سرا',
#   'يلي',
#   'وقدرته',
#   'على',
#   'تصفية',
#   'الحساب',
#   'مع',
#   'رهاب',
#   'حزب',
#   'اله',
#   'صبحت',
#   'مشاكل',
#   'المنطقة',
#   'نابعة',
#   'من',
#   'دور',
#   'سعودي',
#   'مفتقد',
#   'لى',
#   'الطاقات',
#   'الذهنية',
#   'والعسكرية'],
#  ['فلم',
#   'يفيقوا',
#   'حتى',
#   'من',
#   'غفلتهم',
#   'يا',
#   'لهم',
#   'من',
#   'قوم',
#   'فامريكا',
#   'تقول',
#   'ان',
#   'لا',
#   'حاجة',
#   'لها',
#   'بالسعودية'],
#  ['ولماستعادة',
#   'الرمادى',
#   'وما',
#   'الفرق',
#   'بين',
#   'ذلك',
#   'التنظيم',
#   'والحشد',
#   'الايرانى'],
#  ['نحن',
#   'تكفرين',
#   'نتم',
#   'مدا',
#   'عنكم',
#   'لستم',
#   'تكفرين',
#   'لن',
#   'تكفر',
#   'اهلى',
#   'السنة',
#   'وتسبونهم',
#   'هدا',
#   'ليسه',
#   'تكفيرى',
#   'خبتم'],
#  ['لماذا',
#   'يا',
#   'مالكي',
#   'الجزيرة',
#   'وموظفيها',
#   'الاعلامين',
#   'لا',
#   'تظهروا',
#   'الاخبار',
#   'الجيدة',
#   'لدولة',
#   'الاسلامية',
#   'بالعراق',
#   'والشام',
#   'مع',
#   'العلم',
#   'انكم',
#   'تظهرون',
#   'احيانا',
#   'اخبار',
#   'تافهة',
#   'من',
#   'كل',
#   'مكان'],
#  ['تعليق', 'غبي'],
#  ['داعش',
#   'تنظيم',
#   'صادق',
#   'وصريح',
#   'يعبر',
#   'عن',
#   'ال',
#   'سلام',
#   'السياسي',
#   'بكل',
#   'وضوح',
#   'بدون',
#   'قناع',
#   'الخداع',
#   'والتقية',
#   'بنكيران',
#   'هو',
#   'البغدادي',
#   'والغنوشي',
#   'هو',
#   'الظواهري',
#   'ومرسي',
#   'هوالجولاني'],
#  ['بدا',
#   'موقف',
#   'حمد',
#   'منصور',
#   'واضحا',
#   'حين',
#   'جرا',
#   'الحوار',
#   'مع',
#   'مير',
#   'القاعدة',
#   'الجولاني',
#   'وبدا',
#   'مبسوطا',
#   'برفقته',
#   'مساندا',
#   'را',
#   'ومطريا',
#   'على',
#   'عماله',
#   'تصور',
#   'حواره',
#   'مع',
#   'سير',
#   'كان',
#   'يحارب',
#   'القاعدة',
#   'التي',
#   'هاجمت',
#   'بلاده'],
#  ['كيف'],
#  ['تدليس', 'الجزيرة', 'لضحك', 'على', 'السذ'],
#  ['قارن',
#   'حوار',
#   'حمد',
#   'منصور',
#   'مع',
#   'الجولاني',
#   'ستنطاقه',
#   'لهذا',
#   'العقيد',
#   'ال',
#   'سير',
#   'رجو',
#   'النشر',
#   'شكرا'],
#  ['صحافي',
#   'لعنة',
#   'اله',
#   'على',
#   'هذه',
#   'الصحافة',
#   'بوليسي',
#   'يجب',
#   'محاكمة',
#   'هذا',
#   'المهرج',
#   'المصري',
#   'العميل',
#   'رهابين'],
#  ['طبعا',
#   'لا',
#   'قيمة',
#   'لكم',
#   'عندهم',
#   'ولا',
#   'عند',
#   'الناس',
#   'ونتمنى',
#   'اعدامكم',
#   'على',
#   'السريع',
#   'لانكم',
#   'طغاة',
#   'العصر'],
#  ['سلامي',
#   'لنصرة',
#   'لاسير',
#   'يتكلم',
#   'بحرية',
#   'تامة',
#   'وهذا',
#   'يدل',
#   'على',
#   'الاخلاق',
#   'العلية',
#   'والرفيعة',
#   'لمجاهدي',
#   'النصرة'],
#  ['الهم',
#   'احصهم',
#   'عدا',
#   'واقتلهم',
#   'بدا',
#   'ولا',
#   'تغادر',
#   'منهم',
#   'احدا',
#   'هذا',
#   'الدعا',
#   'لجميع',
#   'الذين',
#   'ذكرهم',
#   'وجميع',
#   'المجرمين',
#   'امين',
#   'الهم',
#   'اهلك',
#   'الظالمين',
#   'الهم',
#   'امين',
#   'وصلى',
#   'اله',
#   'على',
#   'محمد',
#   'وعلى',
#   'اله',
#   'وصحبه',
#   'وسلم'],
#  ['من',
#   'الواضح',
#   'هناك',
#   'تنسيق',
#   'عالي',
#   'المستوى',
#   'بين',
#   'الجزيرة',
#   'وقيادات',
#   'جبهة',
#   'النصرة',
#   'ومن',
#   'المعلوم',
#   'هذا',
#   'التنسيق',
#   'لا',
#   'يمكن',
#   'حدوثه',
#   'بمعزل',
#   'عن',
#   'المخابرات',
#   'المنخرطة',
#   'في',
#   'الحرب',
#   'على',
#   'الدولة',
#   'ال',
#   'سلامية'],
#  ['جبهة',
#   'النصرة',
#   'بارك',
#   'اله',
#   'فيكي',
#   'انا',
#   'نظرتي',
#   'لم',
#   'تخب',
#   'بكم',
#   'يوما',
#   'والرجا',
#   'ان',
#   'نرا',
#   'الشبيح',
#   'الطيار',
#   'عبود',
#   'جثه',
#   'هامده',
#   'عبرة',
#   'لكل',
#   'علوي',
#   'كلب',
#   'حقير'],
#  ['ضابط', 'مخابرات', 'مدرب', 'على', 'الكذب', 'مجرم', 'اسدي'],
#  ['احمد',
#   'منصور',
#   'انسان',
#   'متعصب',
#   'اخوان',
#   'مسلمين',
#   'ومن',
#   'الطبيعي',
#   'ان',
#   'يدير',
#   'الحوار',
#   'بهذه',
#   'الطريقة',
#   'ال',
#   'يمة',
#   'التي',
#   'لا',
#   'تمثل',
#   'اخلاق',
#   'السورين',
#   'اخس',
#   'على',
#   'الزمان',
#   'الي',
#   'خلى',
#   'كل',
#   'متخلفين',
#   'العالم',
#   'يتمرجلوا',
#   'على',
#   'السورين'],
#  ['لعنك',
#   'اله',
#   'يا',
#   'حمد',
#   'منصور',
#   'يا',
#   'بن',
#   'الحرام',
#   'اله',
#   'راح',
#   'يفرجيك',
#   'يوم',
#   'باهلك',
#   'واولادك'],
#  ['يجب', 'قتل', 'الطيارين', 'وعدم', 'مبادلتهم', 'ثمن'],
#  ['جيش',
#   'الهر',
#   'العلماني',
#   'يكاد',
#   'يكون',
#   'حبر',
#   'على',
#   'الورق',
#   'الثور',
#   'اسلامية',
#   'رغم',
#   'محاولة',
#   'ال',
#   'علام',
#   'العميل',
#   'طمس',
#   'الحقيقة'],
#  ['شكرا',
#   'الجزيرة',
#   'على',
#   'دعمكم',
#   'لشعب',
#   'السوري',
#   'والثورة',
#   'السورية',
#   'الحرة',
#   'لانها',
#   'تدافع',
#   'عن',
#   'العرب',
#   'اجمع',
#   'من',
#   'خلال',
#   'كسر',
#   'انف',
#   'ايران',
#   'وحزب',
#   'الات',
#   'في',
#   'الارض',
#   'السوية'],
#  ['ومن',
#   'اعرض',
#   'عن',
#   'ذكري',
#   'فان',
#   'له',
#   'معيشة',
#   'ضنكى',
#   'صدق',
#   'اله',
#   'العظيم',
#   'لانى',
#   'تركنا',
#   'ذكر',
#   'اله',
#   'فنحن',
#   'نعيش',
#   'بضنك',
#   'سوا',
#   'بحكام',
#   'يدعون',
#   'الاسلام',
#   'وهو',
#   'بر',
#   'منهم',
#   'الا',
#   'بعضهم',
#   'او',
#   'من',
#   'خلال',
#   'غزونا',
#   'من',
#   'قبل',
#   'الغرب',
#   'الذي',
#   'يرسم',
#   'لنا',
#   'طريقة',
#   'عيشنا'],
#  ['لمرة', 'العاشرة', 'القافلة', 'تسير'],
#  ['التق'],
#  ['لا',
#   'جديد',
#   'كذب',
#   'في',
#   'كذب',
#   'نفس',
#   'تعليقات',
#   'زعيم',
#   'الجنوب',
#   'البناني',
#   'وزعيم',
#   'الحوثين',
#   'نتمنى',
#   'من',
#   'الشعب',
#   'الايراني',
#   'يتخلص',
#   'من',
#   'لا',
#   'السفاحين'],
#  ['ولما', 'نتنياهو', 'سيقسم', 'الاقصى', 'هل', 'لكم', 'خصا', 'الرجال'],
#  ['اضرب',
#   'يا',
#   'سيسي',
#   'بيد',
#   'من',
#   'حديد',
#   'على',
#   'الاخوان',
#   'الارهابين',
#   'موتو',
#   'بغيظكم'],
#  ['كس',
#   'امكم',
#   'قناة',
#   'حقيرة',
#   'ارهابية',
#   'اغونجية',
#   'وداعشية',
#   'وكس',
#   'ام',
#   'كل',
#   'الاعلامين',
#   'والاعلاميات',
#   'تبعكم',
#   'ارهابين',
#   'اخونجين',
#   'اسلامين'],
#  ['ذلك',
#   'اليهوذى',
#   'يسعىلتوسيع',
#   'حرب',
#   'السورين',
#   'واين',
#   'السنة',
#   'محكومين',
#   'من',
#   'عملا',
#   'الصهيونين'],
#  ['يقول',
#   'اليهوذى',
#   'انه',
#   'لم',
#   'يدعوا',
#   'لتعب',
#   'من',
#   'بعد',
#   'فاخرجوا',
#   'ما',
#   'بجعبتكم',
#   'وايران',
#   'يا',
#   'يهوذ'],
#  ['فلقدقاله',
#   'الشيعى',
#   'فعملا',
#   'العرب',
#   'هم',
#   'من',
#   'يمولون',
#   'ايران',
#   'لتات',
#   'لتبيذهم',
#   'بارضهم'],
#  ['وامريكا',
#   'من',
#   'تزود',
#   'حزب',
#   'اسرا',
#   'يل',
#   'عن',
#   'الثوار',
#   'السوريون',
#   'بطا',
#   'رات',
#   'من',
#   'غير',
#   'طيار',
#   'عبر',
#   'الجيش',
#   'البنانى',
#   'بالقلمون',
#   'ويجب',
#   'ان',
#   'يعلمه',
#   'الثوار',
#   'يا',
#   'جزيرة',
#   'ان',
#   'كنت',
#   'صادقة'],
#  ['لا',
#   'يجب',
#   'ان',
#   'تقولى',
#   'الحقيقةيالجزيرة',
#   'الشيعية',
#   'فامريكاتدعم',
#   'حزب',
#   'الات',
#   'بالقلمون'],
#  ['والشيعى',
#   'قال',
#   'الحقيقة',
#   'فمن',
#   'يدعم',
#   'ايران',
#   'ضدالعرب',
#   'هى',
#   'قطروالامارات',
#   'والسعودية'],
#  ['ياسر',
#   'الزعاترة',
#   'تقمص',
#   'احمد',
#   'سعيد',
#   'طنان',
#   'ذاعة',
#   'صوت',
#   'العرب',
#   'الهم',
#   'ما',
#   'رجع',
#   'الحكمة'],
#  ['المذيعه',
#   'العاهره',
#   'هذي',
#   'اش',
#   'اسمها',
#   'شكلها',
#   'اكبر',
#   'عاهره',
#   'في',
#   'فرنسيه',
#   'محجبه',
#   'وارخص',
#   'عاهره',
#   'مستاجره'],
#  ['فين', 'تعليقاتي'],
#  ['اين',
#   'هو',
#   'هذا',
#   'الزخم',
#   'الدولي',
#   'والباكستان',
#   'وتركيا',
#   'ومصر',
#   'لا',
#   'يريدون',
#   'ارسال',
#   'قوات',
#   'برية',
#   'لتقاتل',
#   'نيابة',
#   'عن',
#   'السعودين'],
#  ['اى', 'حزم', 'دولى', 'داعم', 'لكم', 'يا', 'عملا'],
#  ['الكل',
#   'يشتي',
#   'جز',
#   'من',
#   'تعاطف',
#   'السعودية',
#   'موالهم',
#   'داخل',
#   'الوطن',
#   'وخارجها',
#   'وطز',
#   'في',
#   'الشعب',
#   'المسكين',
#   'الذي',
#   'هو',
#   'الضحية',
#   'الحقيقية',
#   'بمعنى',
#   'كل',
#   'واحد',
#   'بيدور',
#   'مصلحة',
#   'نفسة',
#   'ولا',
#   'وطز',
#   'في',
#   'الوطن'],
#  ['تخفيض',
#   'الرواتب',
#   'والتقية',
#   'تمنعهم',
#   'من',
#   'ايقاف',
#   'المهربين',
#   'احباب',
#   'الحسين',
#   'يظنون',
#   'ان',
#   'العراق',
#   'حسينية',
#   'فقط',
#   'لطم',
#   'وطبخ',
#   'الهريس'],
#  ['ما', 'سر', 'قوة', 'تنظيم', 'الدولة'],
#  ['شيوعى',
#   'ملحد',
#   'لخير',
#   'مثال',
#   'من',
#   'يدافع',
#   'عن',
#   'تنظيم',
#   'صهيونى',
#   'وليسوا',
#   'الا',
#   'عملا',
#   'الامريكان',
#   'وصنعتهم',
#   'السى',
#   'اى',
#   'اى'],
#  ['فتنظيم',
#   'القاعدة',
#   'دمرت',
#   'به',
#   'امريكا',
#   'العراق',
#   'ولمدن',
#   'وارض',
#   'السنة',
#   'وابنا',
#   'هم',
#   'وبالنامبلام',
#   'يا',
#   'فيصل',
#   'القاسم',
#   'وسلمتهم',
#   'لصفوين',
#   'بالدرديل'],
#  ['ذلك',
#   'الشيوعى',
#   'الملحد',
#   'عميل',
#   'الامريكان',
#   'والتنظيم',
#   'يصف',
#   'الشرفا',
#   'بالعملا'],
#  ['تفكيرك',
#   'منطقي',
#   'بالنسبة',
#   'لشخص',
#   'لاي',
#   'من',
#   'باله',
#   'واليوم',
#   'ال',
#   'خر',
#   'ما',
#   'من',
#   'رضي',
#   'باله',
#   'ربا',
#   'والاسلام',
#   'دينا',
#   'ومحمد',
#   'صلى',
#   'اله',
#   'عليه',
#   'وعلى',
#   'له',
#   'وصحبه',
#   'وسلم',
#   'رسولا',
#   'فلا',
#   'دين',
#   'ولا',
#   'حكم',
#   'يرضيه',
#   'لا',
#   'حكم',
#   'اله',
#   'لكم',
#   'دينكم',
#   'ولي',
#   'دين'],
#  ['المرادي', 'هو', 'شيوعي', 'شيعي', 'سني', 'متطرف', 'وله', 'مسخره'],
#  ['الجزيرة',
#   'مقدم',
#   'البرنامج',
#   'كانا',
#   'مع',
#   'الثورة',
#   'السورية',
#   'ما',
#   'ال',
#   'فهما',
#   'مع',
#   'داعش',
#   'لا',
#   'نعرف',
#   'غدا',
#   'مع',
#   'من'],
#  ['روح',
#   'شوفلك',
#   'بسه',
#   'العلب',
#   'معها',
#   'احسنلك',
#   'لانه',
#   'كله',
#   'دعايات',
#   'فاشله',
#   'وحقيره',
#   'ضد',
#   'الدوله',
#   'الاسلامية',
#   'لن',
#   'نصدقها',
#   'ابدا',
#   'باقيه',
#   'وتمد',
#   'ذن',
#   'اله'],
#  ['انا',
#   'كنت',
#   'انتظر',
#   'في',
#   'اي',
#   'لحظة',
#   'تدخل',
#   'الشرطة',
#   'القطرية',
#   'لتلقي',
#   'القبض',
#   'على',
#   'المباشر',
#   'على',
#   'دلك',
#   'الدي',
#   'كان',
#   'يدعوش',
#   'على',
#   'الشاشة',
#   'مباشرة',
#   'دلك',
#   'بحكم',
#   'انخراط',
#   'قطر',
#   'في',
#   'محاربة',
#   'داعش'],
#  ['قال',
#   'احد',
#   'الحكما',
#   'كل',
#   'دا',
#   'وجدت',
#   'له',
#   'دوا',
#   'الا',
#   'الاحمق',
#   'لا',
#   'عندهم',
#   'سلس',
#   'بول',
#   'في',
#   'الدماغ',
#   'باقيه',
#   'رغم',
#   'انوفهم',
#   'وتمد',
#   'بحول',
#   'اله',
#   'وقوته'],
#  ['لا', 'عتقد', 'نه', 'يوجد', 'لك', 'عقل', 'ليتلاشى'],
#  ['ترهات',
#   'تعيدها',
#   'مثل',
#   'البغا',
#   'مت',
#   'بغيظك',
#   'ودولة',
#   'الخلافة',
#   'الاسلامية',
#   'باقية',
#   'وتمد',
#   'باذن',
#   'اله'],
#  ['سبحان',
#   'اله',
#   'اني',
#   'احس',
#   'ان',
#   'صاحب',
#   'الحية',
#   'منافق',
#   'ودجال',
#   'ومثل',
#   'ولكن',
#   'فاشل'],
#  ['انت',
#   'ارهابي',
#   'قذر',
#   'دولتك',
#   'الاسلامية',
#   'الارهابية',
#   'القذرة',
#   'داعش',
#   'المتخلفة',
#   'ستسحق',
#   'تحت',
#   'اقدام',
#   'الجيش',
#   'السوري',
#   'البطل',
#   'وايضا',
#   'تحت',
#   'اقدام',
#   'الجيش',
#   'المصري',
#   'والبناني',
#   'واليبي',
#   'الابطال'],
#  ['الشيوعين', 'ارهابين', 'مثل', 'الاسلامين', 'لا', 'فرق', 'بينهم'],
#  ['تمد'],
#  ['وكيف',
#   'سيتعامل',
#   'حكم',
#   'عميل',
#   'مع',
#   'احرار',
#   'فالويل',
#   'بالشعب',
#   'الاردنى',
#   'وشعوبنا',
#   'العربية',
#   'تح',
#   'حكم',
#   'عملا',
#   'المستعمرين',
#   'ولن',
#   'سيدوم'],
#  ['ما',
#   'قالته',
#   'ضيفتكم',
#   'جمانا',
#   'غنيمات',
#   'ما',
#   'هوالا',
#   'كلام',
#   'مستهلك',
#   'اعلاميا',
#   'ونعرفه',
#   'كمشاهدين',
#   'لا',
#   'ادري',
#   'كيف',
#   'تشغل',
#   'منصب',
#   'يس',
#   'تحرير',
#   'لجريدة',
#   'اردنية',
#   'يتناولها',
#   'الكثير',
#   'من',
#   'الناس'],
#  ['فحسن',
#   'نصر',
#   'ليرة',
#   'هو',
#   'اكبر',
#   'عميل',
#   'لاسرا',
#   'يل',
#   'وهى',
#   'من',
#   'تحمى',
#   'ظهره',
#   'بينما',
#   'يحارب',
#   'الشعب',
#   'السورى',
#   'نيابةعنهم',
#   'وان',
#   'خلفهم',
#   'يصفونه',
#   'وكذلك',
#   'الاسد',
#   'الصهيونى'],
#  ['السعود',
#   'تمنع',
#   'وصول',
#   'الحرب',
#   'ال',
#   'لبنان',
#   'عن',
#   'الت',
#   'تد',
#   'الارهاب',
#   'سور'],
#  ['حزب',
#   'الصفوين',
#   'لاراه',
#   'الا',
#   'صناعة',
#   'صهيوصليبية',
#   'برعاية',
#   'المجوس',
#   'ايها',
#   'الصغير'],
#  ['سنقتلع', 'جذرةذلك', 'حزب', 'ايران', 'اسرا', 'يل'],
#  ['هذا', 'التقرير', 'ينقصه', 'اسما', 'وصفات', 'الضيوف'],
#  ['فلا', 'تقرا', 'تعليقى'],
#  ['ثلات', 'اسابيع', 'من', 'الاعتدا'],
#  ['ملة', 'الكفر', 'واحدة'],
#  ['الكفر', 'ملة', 'واحدة', 'والاسلام', 'ضد', 'لا', 'جميعهم'],
#  ['كبر',
#   'على',
#   'الجزيرة',
#   'ان',
#   'تنشر',
#   'مثل',
#   'هذه',
#   'الطلاسم',
#   'الغوية',
#   'والرقمية',
#   'على',
#   'صفحاتها',
#   'فهنا',
#   'تنطبق',
#   'الحكمة',
#   'التي',
#   'تقول',
#   'قل',
#   'لي',
#   'من',
#   'قر',
#   'قول',
#   'لك',
#   'من',
#   'انت'],
#  ['الامارات',
#   'تسحب',
#   'قواتها',
#   'من',
#   'اليمن',
#   'بعد',
#   'مقتل',
#   'العشرات',
#   'جرح',
#   'الم',
#   'ات',
#   'من',
#   'جنودها',
#   'بعد',
#   'ان',
#   'ادركت',
#   'ان',
#   'اليمن',
#   'مقبرة',
#   'لغزاة'],
#  ['اين',
#   'طرف',
#   'اخر',
#   'يا',
#   'الخنزيرة',
#   'هل',
#   'ترى',
#   'ان',
#   'المشاهد',
#   'ساذيج',
#   'لا',
#   'يعرف',
#   'ما',
#   'يجري',
#   'في',
#   'اليمن',
#   'يا',
#   'لقطا',
#   'البشرية',
#   'مضيف',
#   'اربعة',
#   'كلاب',
#   'ينبح',
#   'بسنفونية',
#   'ال',
#   'سلولي',
#   'قطرا',
#   'يلية',
#   'تفو',
#   'على',
#   'شرفكم'],
#  ['مجلس', 'الفستق'],
#  ['يجب',
#   'محاكمتكم',
#   'يا',
#   'بغاة',
#   'يا',
#   'صعاليك',
#   'يا',
#   'مجرمين',
#   'يا',
#   'عملا',
#   'وليس',
#   'اعمار',
#   'اليمن'],
#  ['اى',
#   'انتخابات',
#   'واى',
#   'نتا',
#   'وعلى',
#   'اىقاعدة',
#   'التىتقول',
#   'المتاسلمين',
#   'يلهفون',
#   'علىالحكم',
#   'بيع',
#   'كلام',
#   'اله',
#   'وبالمساومة'],
#  ['اعجبني',
#   'الثوب',
#   'الفلسطيني',
#   'المطرز',
#   'الذي',
#   'ترتديه',
#   'سيدة',
#   'الاخبار',
#   'العربيه',
#   'ايمان',
#   'بنوره'],
#  ['لسنا',
#   'بحاجه',
#   'لمحل',
#   'اقتصادي',
#   'لتفسير',
#   'ما',
#   'يحدث',
#   'الامر',
#   'بساطه',
#   'عندما',
#   'يتولى',
#   'يس',
#   'عصابه',
#   'ادارة',
#   'ون',
#   'البلاد',
#   'مافيا',
#   'تسير',
#   'امور',
#   'الناس',
#   'يودو',
#   'البلد',
#   'بستين',
#   'داهيه'],
#  ['المعادلة',
#   'سترسمها',
#   'الثورة',
#   'بدما',
#   'شعوبنا',
#   'الزكية',
#   'ولا',
#   'يات',
#   'احد',
#   'يات',
#   'فوقها',
#   'ولا',
#   'امريكا',
#   'اما',
#   'ايران',
#   'فحسابها',
#   'عسير',
#   'ونحن',
#   'شعوب',
#   'وه',
#   'لا',
#   'كلهم',
#   'لاش'],
#  ['اى',
#   'معادلة',
#   'واله',
#   'لن',
#   'يحكمون',
#   'عملا',
#   'اليهوذ',
#   'الاذاشعوبنا',
#   'ليسوا',
#   'بشعوب'],
#  ['فالامة',
#   'الاسلامية',
#   'يحكمها',
#   'الا',
#   'عملا',
#   'اليهوذ',
#   'ولو',
#   'لا',
#   'تنشريه',
#   'يا',
#   'جزيرة',
#   'هو',
#   'الحقيقة'],
#  ['عميل',
#   'ايراني',
#   'بامتياز',
#   'ولا',
#   'تصدقون',
#   'كل',
#   'ما',
#   'يقول',
#   'فهو',
#   'ثعلب',
#   'يستعمل',
#   'التقيه',
#   'الشيعيه'],
#  ['من',
#   'المتوقع',
#   'ان',
#   'تعز',
#   'العلاقات',
#   'بين',
#   'دول',
#   'المنطقة',
#   'حيث',
#   'سيزداد',
#   'معدل',
#   'التبادل',
#   'الارهابي',
#   'بينهم',
#   'لن',
#   'يبقى',
#   'تصدير',
#   'الارهابين',
#   'حكرا',
#   'على',
#   'دول',
#   'معينة',
#   'سيكون',
#   'لهذا',
#   'التبادل',
#   'في',
#   'مجال',
#   'الارهاب',
#   'اثره',
#   'في',
#   'عودة',
#   'الاستقرار'],
#  ['يا',
#   'ابن',
#   'المتعة',
#   'الكاذب',
#   'واله',
#   'تمنى',
#   'رحيل',
#   'كل',
#   'العراب',
#   'لدعم',
#   'الزنادقة',
#   'الحوثين'],
#  ['لاتخف',
#   'فلم',
#   'يقصر',
#   'معنا',
#   'خوتنا',
#   'العرب',
#   'فقد',
#   'جا',
#   'ونا',
#   'بالذبح',
#   'لقطع',
#   'رقابنا',
#   'ونحمد',
#   'اله',
#   'كذلك',
#   'على',
#   'محبة',
#   'اخوتنا',
#   'الشيشان',
#   'الذين',
#   'فجروا',
#   'مدنا'],
#  ['تكلم',
#   'يا',
#   'مجرم',
#   'عن',
#   'بشار',
#   'بانه',
#   'دكتور',
#   'لا',
#   'يكذب',
#   'كمان',
#   'انت',
#   'دكتور',
#   'يا',
#   'حقير',
#   'مجرم',
#   'اكثر',
#   'منه',
#   'مجازرك',
#   'معروفه',
#   'كلكم',
#   'تشربوا',
#   'من',
#   'نفس',
#   'النبع',
#   'يا',
#   'قتله'],
#  ['يريد',
#   'ان',
#   'يغطي',
#   'الشمس',
#   'بالغربال',
#   'قطعان',
#   'رافضية',
#   'مدعومة',
#   'بطيران',
#   'صليبي',
#   'لقتل',
#   'السنة',
#   'قد',
#   'وجدنا',
#   'الدا',
#   'دوا',
#   'كم',
#   'ابو',
#   'بكر',
#   'البغدادي'],
#  ['في', 'يوم', 'ما', 'كنت', 'اعتقد', 'ان', 'الجعفري', 'شخص', 'ذكي'],
#  ['يسمونه', 'حرس', 'وطنىوليس', 'حرس', 'الاحتلال', 'حقيقته'],
#  ['خيل', 'خوبي'],
#  ['كلاب',
#   'البعث',
#   'كثروا',
#   'النباح',
#   'فقد',
#   'خرج',
#   'القطيع',
#   'من',
#   'الحظا',
#   'وصار',
#   'لكم',
#   'ند',
#   'شديد'],
#  ['الهم',
#   'يفك',
#   'اسرهم',
#   'ولشعب',
#   'الاوكرانى',
#   'من',
#   'الروس',
#   'المجرمين',
#   'المحتلين',
#   'امين',
#   'رب',
#   'العالمين'],
#  ['يا',
#   'عمي',
#   'متى',
#   'سوف',
#   'يتوحد',
#   'هل',
#   'السنه',
#   'تحت',
#   'حاكم',
#   'واحد',
#   'واله',
#   'ربنا',
#   'سوف',
#   'يعاقب',
#   'عقاب',
#   'كبير'],
#  ['بلانفاق',
#   'في',
#   'غزه',
#   'حصار',
#   'ويجب',
#   'ان',
#   'يكسر',
#   'وما',
#   'عن',
#   'اليمن',
#   'يا',
#   'جزيره',
#   'وحصار',
#   'عاصغة',
#   'الجرم',
#   'على',
#   'النسا',
#   'الاطفال'],
#  ['وهوفىالحقيقةلويخترقو',
#   'سيقزبونهم',
#   'اسيادهم',
#   'المستعمرين',
#   'والاوروبين',
#   'ولهذا',
#   'هم',
#   'حكام',
#   'المستعمرين',
#   'ولهذا',
#   'مشرعين',
#   'منهم',
#   'بدل',
#   'شعوبهم',
#   'عكس',
#   'شعوب',
#   'الارض',
#   'والاوروبين',
#   'المستقلين',
#   'الاسياد'],
#  ['ال',
#   'وروبيون',
#   'يسعون',
#   'لكسر',
#   'الحصار',
#   'عن',
#   'غزة',
#   'والمنتخب',
#   'السعودي',
#   'يسعى',
#   'لكسر',
#   'المقاطعة',
#   'عن',
#   'سرا',
#   'يل'],
#  ['هذا', 'تظليل', 'والجزيرةتعرفه'],
#  ['ية',
#   'اله',
#   'العظمى',
#   'الفرعون',
#   'السيسي',
#   'يدعو',
#   'الى',
#   'تفويض',
#   'ليقوم',
#   'بانقلاب',
#   'عفوا',
#   'اقصد',
#   'ثورة',
#   'في',
#   'الخطاب',
#   'الديني',
#   'لسان',
#   'حاله',
#   'يقول',
#   'اتعبدوه',
#   'قبل',
#   'اذن',
#   'لكم'],
#  ['لا',
#   'رى',
#   'حرج',
#   'في',
#   'حرق',
#   'مطبوعات',
#   'تروج',
#   'لذبح',
#   'القتل',
#   'التفجير',
#   'تستر',
#   'بالدين',
#   'بل',
#   'انه',
#   'من',
#   'واجب',
#   'كل',
#   'مسلم',
#   'الانتظام',
#   'لهذه',
#   'المحرقة',
#   'دفاعا',
#   'عن',
#   'ال',
#   'سلام',
#   'المسالم',
#   'الصحيح',
#   'الذي',
#   'لوثته',
#   'هذه',
#   'المطبوعات',
#   'المتطرفة'],
#  ['هذه',
#   'الشعوب',
#   'محكومةعليها',
#   'بكل',
#   'المصا',
#   'والعنف',
#   'ولانها',
#   'ليست',
#   'شعوب',
#   'حقيقة'],
#  ['السحر',
#   'انلقب',
#   'على',
#   'الساحر',
#   'والارهاب',
#   'خرج',
#   'عن',
#   'السيطرة',
#   'وناره',
#   'تمتد',
#   'الى',
#   'من',
#   'صنعوه'],
#  ['الى',
#   'جهنم',
#   'وب',
#   'المصير',
#   'كان',
#   'نجسا',
#   'مجرما',
#   'سافلا',
#   'وحقيرا',
#   'وسياتي',
#   'يوم',
#   'على',
#   'سواه',
#   'ان',
#   'شا',
#   'اله'],
#  ['نعم',
#   'يحكمونا',
#   'اليهوذ',
#   'ومنذ',
#   'سقوط',
#   'اخر',
#   'دولة',
#   'اسلامية',
#   'الخلافة',
#   'العثمانية',
#   'وهو',
#   'تاريخنا',
#   'الحقيقى'],
#  ['طقاطيق',
#   'مصاحبة',
#   'لعرض',
#   'زيا',
#   'سياسية',
#   'عربية',
#   'فوق',
#   'رقص',
#   'الموت',
#   'من',
#   'تركيب',
#   'غسان',
#   'شبانة',
#   'في',
#   'منظومة',
#   'العنكبوت',
#   'الخليجية'],
#  ['سبحان',
#   'اله',
#   'لا',
#   'تعليق',
#   'لا',
#   'اهتمام',
#   'بالش',
#   'الصهيوني',
#   'هذا',
#   'حال',
#   'العربان',
#   'اليوم'],
#  ['كان', 'ال', 'فضل', 'لكم', 'قرا', 'صلاة', 'الموتى'],
#  ['انه',
#   'ليس',
#   'صراع',
#   'بل',
#   'ثورة',
#   'على',
#   'حكم',
#   'اليهوذ',
#   'وذلك',
#   'ثمن',
#   'كل',
#   'من',
#   'يسعى',
#   'لتحر',
#   'منهم',
#   'واجب'],
#  ['ان',
#   'الشعب',
#   'السورى',
#   'بثورته',
#   'وثواره',
#   'ليس',
#   'الا',
#   'وجها',
#   'الا',
#   'لايران',
#   'عدوة',
#   'اله',
#   'والمسلمين',
#   'بل',
#   'وجها',
#   'لصهاينة',
#   'العالم',
#   'اجمعين',
#   'والتى',
#   'ايران',
#   'الصهيونية',
#   'الا',
#   'جز',
#   'منهم'],
#  ['اقر',
#   'التورات',
#   'سفر',
#   'دانيال',
#   'العد',
#   'فرس',
#   'قسمت',
#   'ملكتك',
#   'اي',
#   'بابل',
#   'سوريا',
#   'الكبرى',
#   'اعطيت',
#   'لمادي',
#   'اي',
#   'الكرد',
#   'فارس',
#   'اي',
#   'ايران'],
#  ['هدا',
#   'ما',
#   'كان',
#   'يتمناه',
#   'السيسي',
#   'ويدفع',
#   'لى',
#   'تحقيقه',
#   'ال',
#   'رهاب',
#   'المحتمل',
#   'وقد',
#   'وقع'],
#  ['واله',
#   'ان',
#   'الموت',
#   'قليل',
#   'على',
#   'لا',
#   'فقد',
#   'اجرموا',
#   'بحق',
#   'ال',
#   'لاف',
#   'من',
#   'ابنا',
#   'هذا',
#   'الشعب',
#   'بدون',
#   'جريرة',
#   'ارتكبوها',
#   'فلو',
#   'مات',
#   'امثال',
#   'هذا',
#   'المجرم',
#   'الف',
#   'مرة',
#   'لكان',
#   'قليل',
#   'عليه'],
#  ['مكان'],
#  ['بشر',
#   'القاتل',
#   'بالقتل',
#   'ولو',
#   'بعد',
#   'حين',
#   'كنا',
#   'نتمنى',
#   'له',
#   'ذبحا',
#   'على',
#   'يدي',
#   'رجال',
#   'الدولة'],
#  ['نبيل',
#   'ميخا',
#   'يل',
#   'يكن',
#   'حقد',
#   'على',
#   'الاسلام',
#   'والمسلمين',
#   'ولا',
#   'يهمه',
#   'اى',
#   'عن',
#   'حقوق',
#   'الانسان',
#   'والظلم',
#   'الذى',
#   'وقع',
#   'بالمصرين',
#   'بعد',
#   'الانقلاب',
#   'فكل',
#   'تعليقاته',
#   'تصب',
#   'فى',
#   'حمايه',
#   'الاقله',
#   'المسيحيه',
#   'بمصر',
#   'ومسانده',
#   'الانقلاب'],
#  ['هيه',
#   'مافعل',
#   'بناقزم',
#   'دولةعربية',
#   'وجا',
#   'الثورة',
#   'والحمدله',
#   'وسنعريك',
#   'يا',
#   'ايران',
#   'لاخر',
#   'الثياب',
#   'ولانا',
#   'اليه',
#   'لقادرين',
#   'باذن',
#   'اله'],
#  ['من',
#   'يفجر',
#   'المساجد',
#   'والمستشفيات',
#   'والاسواق',
#   'في',
#   'السعودية',
#   'واليمن',
#   'والكويت',
#   'والعراق',
#   'وسوريا',
#   'هي',
#   'الطا',
#   'فة',
#   'الخطيرة',
#   'على',
#   'المنطقه',
#   'وهذه',
#   'البرامج',
#   'والقنوات',
#   'البغيضة',
#   'هي',
#   'التي',
#   'تدفع',
#   'الشباب',
#   'لانتحار',
#   'وقتل',
#   'الابريا'],
#  ['دور',
#   'يران',
#   'في',
#   'نشر',
#   'الطا',
#   'فية',
#   'قل',
#   'من',
#   'واحد',
#   'لف',
#   'عن',
#   'دور',
#   'السعودية',
#   'التي',
#   'تكفر',
#   'الطوا',
#   'والمذاهب',
#   'الاخرى',
#   'وتقصف',
#   'وتفجر',
#   'المساجد',
#   'والمستشفيات',
#   'وترسل',
#   'الانتحارين',
#   'لى',
#   'دول',
#   'الجوار'],
#  ['هل', 'جمول', 'شيعي'],
#  ['بنظري',
#   'هم',
#   'عامل',
#   'لحد',
#   'من',
#   'انتشار',
#   'المرض',
#   'ضرورة',
#   'توعية',
#   'الشباب',
#   'بعدم',
#   'الزواج',
#   'بين',
#   'من',
#   'يعانون',
#   'من',
#   'مرض',
#   'السكري',
#   'وهذا',
#   'يحتاج',
#   'الى',
#   'جهد',
#   'مضاعف',
#   'بدل',
#   'التركيز',
#   'على',
#   'منع',
#   'الحمل'],
#  ['فالجزيرة',
#   'نفسها',
#   'ستحول',
#   'بمثل',
#   'صحافة',
#   'حكام',
#   'المستعمرين',
#   'والاعلام',
#   'يجب',
#   'ان',
#   'يكن',
#   'بيدالشعب',
#   'وليس',
#   'بيداحد',
#   'وحر',
#   'مستقل',
#   'بالدول',
#   'المتقدمة'],
#  ['بالعكس',
#   'مصير',
#   'السعوديه',
#   'بين',
#   'التحالف',
#   'الروسي',
#   'الاسدي',
#   'مركسين',
#   'وجدوا',
#   'عدوهم',
#   'في',
#   'حاله',
#   'ضعف',
#   'مشهد',
#   'يذكر',
#   'بم',
#   'ساه',
#   'رومانوف',
#   'بين',
#   'يدي',
#   'من',
#   'لايرحم',
#   'ولاينسى'],
#  ['بين',
#   'اخيب',
#   'دولتين',
#   'بشار',
#   'اقوى',
#   'من',
#   'الروس',
#   'المهزومين',
#   'والسعوديه',
#   'فقدت',
#   'دورها',
#   'من',
#   'زمان',
#   'واصبحت',
#   'مرتزقه',
#   'ومنافقين',
#   'راحت',
#   'ايام',
#   'دجل',
#   'الامه',
#   'العربيه',
#   'والحرمين',
#   'الشريفين',
#   'طارت',
#   'في',
#   'عجه',
#   'صدام',
#   'وبن',
#   'لادن'],
#  ['صدق',
#   'رسول',
#   'اله',
#   'المشرق',
#   'قرنا',
#   'الشيطان',
#   'نجد',
#   'وطهران',
#   'فتنا',
#   'المسلمين',
#   'ومزقا',
#   'كل',
#   'شي',
#   'بحجة',
#   'تافه'],
#  ['انتم',
#   'يا',
#   'يمنى',
#   'ونحن',
#   'شوية',
#   'وستنصبح',
#   'من',
#   'غير',
#   'بلد',
#   'بحكم',
#   'العملا',
#   'الخونة',
#   'المنصبين',
#   'لمستعمر',
#   'بالسعودية',
#   'واليمن',
#   'اصلنا',
#   'لم',
#   'نستفيق',
#   'من',
#   'ان',
#   'دول',
#   'عربية',
#   'بهم',
#   'ضاعت',
#   'وابيدت'],
#  ['لجموع',
#   'صيغ',
#   'وقواعد',
#   'وكل',
#   'الحن',
#   'في',
#   'غزل',
#   'هجا',
#   'بت',
#   'نيث',
#   'المذكر',
#   'تعني',
#   'خفاق',
#   'عراب',
#   'لفية',
#   'عصر'],
#  ['مباشروشي',
#   'فليجعلوا',
#   'بضاعـة',
#   'مزجاة',
#   'لمغلقيها',
#   'حدهم',
#   'ويبقـى',
#   'مغلقا',
#   'لا',
#   'يفتح',
#   'لا',
#   'لا'],
#  ['حتى',
#   'متى',
#   'يدافع',
#   'لا',
#   'المحلون',
#   'المختصون',
#   'حسب',
#   'زعم',
#   'على',
#   'يران',
#   'هذه',
#   'الدولة',
#   'الخرافية',
#   'دولة',
#   'مكابرة',
#   'يكفيها',
#   'ذلا',
#   'الدجال',
#   'سيخرج',
#   'من',
#   'رضها'],
#  ['لو',
#   'كانت',
#   'الدولة',
#   'ال',
#   'سلامية',
#   'على',
#   'باطل',
#   'عطى',
#   'لها',
#   'ال',
#   'علام',
#   'مجال',
#   'لرد',
#   'لكي',
#   'يظهر',
#   'لناس',
#   'صدق',
#   'ما',
#   'يقولون',
#   'عنها',
#   'لكن',
#   'خوفهم',
#   'من',
#   'الحقيقة',
#   'يمنعهم',
#   'حتى',
#   'من',
#   'عرض',
#   'التعليقات',
#   'التي',
#   'تفضح',
#   'المفترين'],
#  ['هذا', 'القيط', 'فضل', 'ينظر', 'لمن', 'يدرب', 'المعارضة', 'قبل', 'الكلام'],
#  ['هل', 'يذهب', 'الاستاذ', 'احمد', 'منصور', 'الي', 'الدولة', 'الاسلامية'],
#  ['قلت',
#   'السعودية',
#   'تحكم',
#   'بكتاب',
#   'اله',
#   'ين',
#   'موال',
#   'الزكاة',
#   'لعلم',
#   'موال',
#   'النفط',
#   'ذا',
#   'كانت',
#   'في',
#   'رض',
#   'يملكها',
#   'مسلم',
#   'فها',
#   'الخمس',
#   'ما',
#   'ذا',
#   'كانت',
#   'في',
#   'رض',
#   'لدولة',
#   'فكلها',
#   'لفقرا',
#   'والمساكين',
#   'ين',
#   'السعودية',
#   'من',
#   'هذا'],
#  ['الموت',
#   'لاسلام',
#   'ال',
#   'مر',
#   'النصر',
#   'لاسلام',
#   'المحمد',
#   'صل',
#   'اله',
#   'عل',
#   'له',
#   'العنه',
#   'عل',
#   'القاعده',
#   'الدواعش',
#   'الوهاب',
#   'عملا',
#   'هود'],
#  ['كتبت',
#   'تعليق',
#   'مشابه',
#   'لكنه',
#   'لم',
#   'ينشر',
#   'لذكري',
#   'سم',
#   'معارض',
#   'سعودي'],
#  ['سمعت',
#   'اله',
#   'اعلم',
#   'او',
#   'ربما',
#   'قر',
#   'ان',
#   'مس',
#   'لة',
#   'عمر',
#   'رضي',
#   'اله',
#   'عنه',
#   'لابنته',
#   'في',
#   'الجاهلية',
#   'رواية',
#   'خاط',
#   'غير',
#   'صحيحة'],
#  ['حركة',
#   'الشباب',
#   'اعزها',
#   'اله',
#   'لم',
#   'تسفك',
#   'دم',
#   'الا',
#   'ملة',
#   'الكفر',
#   'والنفاق',
#   'وهي',
#   'توا',
#   'النصرة'],
#  ['اسفا',
#   'لجز',
#   'ره',
#   'لماذا',
#   'لم',
#   'تنشر',
#   'را',
#   'اه',
#   'ذا',
#   'طر',
#   'قه',
#   'الاحرار'],
#  ['الحولاني'],
#  ['ياله', 'فيلم', 'هندي'],
#  ['عميل',
#   'يتهم',
#   'الشرفا',
#   'ترى',
#   'كم',
#   'من',
#   'الزمن',
#   'لتنجز',
#   'الجزيرة',
#   'حصة',
#   'عن',
#   'مخبر',
#   'النصرة'],
#  ['لا', 'تكن', 'امعة', 'تولانا', 'اله', 'برحمته'],
#  ['اذا',
#   'صدقنا',
#   'حكايتك',
#   'فلنصدق',
#   'حكاية',
#   'الطماطم',
#   'والخيار',
#   'يب',
#   'يد',
#   'تولانا',
#   'اله',
#   'برحمته'],
#  ['هل',
#   'تنتظر',
#   'ال',
#   'نصاف',
#   'من',
#   'حمد',
#   'منصور',
#   'بالذات',
#   'تجاه',
#   'الدولة',
#   'ال',
#   'سلامية',
#   'ربما',
#   'عندما',
#   'يمتلك',
#   'حريته'],
#  ['ونعم', 'الشريعة', 'التي', 'تطبق', 'في', 'السعودية'],
#  ['واله',
#   'لن',
#   'تحكمون',
#   'الشعب',
#   'اليمنى',
#   'واى',
#   'شعب',
#   'عربى',
#   'الا',
#   'بانتخابات',
#   'شعوبنا',
#   'العربية',
#   'وبالعدل',
#   'والديموقراطية',
#   'والمساوات',
#   'يا',
#   'عملا',
#   'المستعمرين',
#   'يا',
#   'يهود',
#   'وعليه',
#   'قامت',
#   'وتظحى',
#   'شعوبنا',
#   'العربية',
#   'ليمن'],
#  ['انها',
#   'ثورة',
#   'الشعب',
#   'السورى',
#   'لتحر',
#   'ولن',
#   'سيغلبها',
#   'الاستعمار',
#   'الصهيوروسى',
#   'صفوى',
#   'ابدا',
#   'واله',
#   'ينصر',
#   'الشعب',
#   'السورى',
#   'امين'],
#  ['لمجهول',
#   'وهو',
#   'ثمن',
#   'عملا',
#   'على',
#   'حكم',
#   'المسلمون',
#   'وعنه',
#   'ستعلم',
#   'الشعوب'],
#  ['نفس',
#   'التعليق',
#   'في',
#   'عدة',
#   'مقالات',
#   'هذا',
#   'ليس',
#   'مجرد',
#   'بل',
#   'تحريض',
#   'على',
#   'العنف',
#   'انتبهو',
#   'لمن',
#   'يريد',
#   'يعود',
#   'بنا',
#   'لى',
#   'الورا'],
#  ['ربما',
#   'لان',
#   'الملا',
#   'كة',
#   'يقاتلون',
#   'مع',
#   'الثوار',
#   'المتعدو',
#   'الجنسيات',
#   'كما',
#   'قاتلوا',
#   'معهم',
#   'في',
#   'حمص',
#   'والقصير'],
#  ['لى',
#   'الجاحدة',
#   'هلا',
#   'عدت',
#   'لنا',
#   'هذه',
#   'الجنسيات',
#   'وهذه',
#   'الفصا',
#   'سبحان',
#   'من',
#   'خلق',
#   'الكذب',
#   'وجعل',
#   'تسعة',
#   'عشاره',
#   'عند',
#   'الروافض',
#   'الشيعة'],
#  ['نت', 'الذى', 'يحتاج', 'هذه', 'المياه', 'الساقعة'],
#  ['كذابون',
#   'منافقون',
#   'لماذا',
#   'لا',
#   'يوجد',
#   'درزي',
#   'يتكلم',
#   'عن',
#   'الدروز',
#   'في',
#   'هذا',
#   'البرنامج',
#   'البارحه',
#   'ثورتكم',
#   'ارتكبة',
#   'مجذرة',
#   'في',
#   'دلب',
#   'وقتلو',
#   'كثر',
#   'من',
#   'ثلاثين',
#   'درزي'],
#  ['قل', 'لذين', 'كفروا', 'ستغلبون'],
#  ['يستضيف',
#   'اثنين',
#   'من',
#   'نغلا',
#   'خرفان',
#   'لكي',
#   'يقيم',
#   'حالة',
#   'السنة',
#   'في',
#   'العراق'],
#  ['هيه',
#   'دسوا',
#   'عورتكم',
#   'ياتجار',
#   'الدين',
#   'وبثورتنا',
#   'لا',
#   'يتماشىمع',
#   'الديموقراطية'],
#  ['شعوب',
#   'مفعول',
#   'بها',
#   'ولا',
#   'تفتح',
#   'فمهاوالا',
#   'قرارعملا',
#   'المستعمرين',
#   'وجيوشهم',
#   'منصبين',
#   'عليها',
#   'حكم',
#   'وبدعم',
#   'المستعمرين',
#   'اسرا',
#   'يل',
#   'ولاجلهم',
#   'حتىانه',
#   'لا',
#   'يجب',
#   'ان',
#   'نسمىها',
#   'شعب'],
#  ['لعن', 'اله', 'الصهاينة', 'العرب', 'قبل', 'اليهود'],
#  ['اخبار', 'العلاقه', 'ايه', 'بين', 'اسرا', 'يل', 'وتركيا', 'وقطر'],
#  ['ايتها', 'الجزيره', 'العميله', 'موتو', 'بغيظكم'],
#  ['وماذا',
#   'عن',
#   'رسالة',
#   'المخلوع',
#   'لشيمون',
#   'بيريز',
#   'صديقك',
#   'الوفي',
#   'محمد',
#   'مرسي'],
#  ['ايش',
#   'رح',
#   'يكون',
#   'ورا',
#   'ها',
#   'يعني',
#   'يا',
#   'جزيرة',
#   'طب',
#   'ما',
#   'المكتب',
#   'صار',
#   'له',
#   'مفتوح',
#   'مليون',
#   'سنة',
#   'في',
#   'قطر',
#   'فيش',
#   'حدا',
#   'بيحكي',
#   'قال',
#   'ماذا',
#   'ورا',
#   'قال'],
#  ['ولماذا', 'تندهش', 'يا', 'صديقي', 'يهودي', 'ناطق', 'بالعربية'],
#  ['انت',
#   'ستعلمنى',
#   'بالمغرب',
#   'حزب',
#   'علال',
#   'الفاسى',
#   'يدعى',
#   'انه',
#   'حصل',
#   'لاستقال',
#   'لمغرب',
#   'روحوا',
#   'اظحكوا',
#   'على',
#   'الذى',
#   'لا',
#   'يعرفكم',
#   'او',
#   'محمد',
#   'الخامس',
#   'ظهر',
#   'بالقمر'],
#  ['الانتصارات',
#   'التي',
#   'يحقثها',
#   'المجاهدون',
#   'في',
#   'سوريا',
#   'خاصة',
#   'جيش',
#   'ال',
#   'سلام',
#   'في',
#   'ريف',
#   'دمشق',
#   'تقول',
#   'لروس',
#   'وال',
#   'يرانين',
#   'نصر',
#   'اله',
#   'قريب'],
#  ['الاستعمار',
#   'الروسى',
#   'لسورية',
#   'وبنظامه',
#   'وجيشه',
#   'الذى',
#   'اجرمب',
#   'السورين',
#   'اشدمن',
#   'النازية',
#   'ليهود',
#   'بالمانيابالحرب',
#   'العالمية',
#   'الثانية'],
#  ['الى',
#   'ابواب',
#   'بيوتكم',
#   'انشا',
#   'اله',
#   'يا',
#   'ملاحده',
#   'تقسيم',
#   'زماني',
#   'ومكاني',
#   'في',
#   'الجمرات',
#   'وتكلمون',
#   'عن',
#   'سياده',
#   'دول',
#   'وحرمات',
#   'اله',
#   'تنتهك',
#   'وعندكم',
#   'قاعده',
#   'امريكيه',
#   'وفرق',
#   'عسكريه',
#   'غربيه'],
#  ['ما',
#   'الذي',
#   'يصنع',
#   'الخبار',
#   'في',
#   'الخنزيرة',
#   'لقيط',
#   'اسر',
#   'يل',
#   'وخنازير',
#   'الخليج'],
#  ['واله',
#   'يالقبايل',
#   'نتما',
#   'شاطرين',
#   'غير',
#   'قدام',
#   'البرانية',
#   'تكبروا',
#   'على',
#   'العروبة',
#   'سلام',
#   'في',
#   'الجزا',
#   'ضعركم',
#   'المخبط',
#   'راكم',
#   'حابين',
#   'لجزاير',
#   'واش',
#   'راه',
#   'صاري',
#   'في',
#   'سوريا',
#   'تذقوها',
#   'وتعضوا',
#   'صباعتكم',
#   'يا',
#   'مقسمين'],
#  ['سيحيا',
#   'ذليلا',
#   'طريدجرا',
#   'مه',
#   'واستبشرو',
#   'خيرا',
#   'فلم',
#   'يت',
#   'حكمالعسكرلى',
#   'شعب',
#   'قرنيل',
#   'حريته',
#   'منحكم',
#   'العسكر'],
#  ['عقل',
#   'جورج',
#   'صبرا',
#   'مرتبك',
#   'بالهندسة',
#   'الماركسية',
#   'عاشت',
#   'الثورة',
#   'ولو',
#   'خذته',
#   'لى',
#   'معسكر',
#   'لموت',
#   'الباحث',
#   'السياسي',
#   'الاستراتيجي',
#   'الباريسي',
#   'عضو',
#   'صيل',
#   'في',
#   'عاصفة',
#   'الحزم'],
#  ['تنظر',
#   'الينانا',
#   'مستعمرين',
#   'من',
#   'الغرب',
#   'وبعملا',
#   'نصبهم',
#   'وصنعهم',
#   'الاستعمار',
#   'لدولنا',
#   'العربية',
#   'وبعدماوهموالامة',
#   'بلاستقلال',
#   'المزعوم',
#   'عن',
#   'الاتراك'],
#  ['لعنة',
#   'اله',
#   'على',
#   'من',
#   'يعتدى',
#   'على',
#   'اليمنين',
#   'والا',
#   'عملا',
#   'فقط',
#   'ومنصبين'],
#  ['فليمحى',
#   'الشعبالسورى',
#   'هذه',
#   'الاقليات',
#   'الصهيونيةقبل',
#   'ما',
#   'يمحوه',
#   'وحق',
#   'وشرع',
#   'وقل',
#   'لبريطانياتدخل',
#   'يامحل',
#   'بل',
#   'جيش',
#   'امريكاوروسياو',
#   'اسرا',
#   'يل',
#   'كمان',
#   'فالشعب',
#   'السورى',
#   'وثورته',
#   'ليست',
#   'حمايةلعملا',
#   'اسرا',
#   'يل',
#   'وايران'],
#  ['سلاح',
#   'ذري',
#   'وليس',
#   'سلاح',
#   'نوي',
#   'من',
#   'فضلكم',
#   'في',
#   'الدقيقة',
#   'من',
#   'الفيديو'],
#  ['يا',
#   'دويله',
#   'قذره',
#   'يا',
#   'اولاد',
#   'الكلب',
#   'الا',
#   'تستحوا',
#   'نتم',
#   'من',
#   'يحكمكم',
#   'هو',
#   'حاكم',
#   'عكه',
#   'يا',
#   'وساخ',
#   'نتم',
#   'شعب',
#   'شاذ',
#   'يحكمكم',
#   'مخنث'],
#  ['طريق',
#   'القدس',
#   'تمر',
#   'بالكويت',
#   'حدا',
#   'يعلم',
#   'السيد',
#   'على',
#   'غوغل',
#   'مابس'],
#  ['حالما',
#   'نتهي',
#   'من',
#   'تسطيح',
#   'جبال',
#   'اليمن',
#   'سنشهد',
#   'عرض',
#   'زيا',
#   'عربية',
#   'ذكورية',
#   'خليجية',
#   'سياسية',
#   'في',
#   'الضاحية',
#   'احتفالا',
#   'بالنصر',
#   'يظهر',
#   'ان',
#   'استبدال',
#   'سعادة',
#   'النا',
#   'خالد',
#   'الظاهر',
#   'بفريق',
#   'عميل',
#   'يقوم',
#   'بنفس',
#   'الدور',
#   'قد',
#   'تكل',
#   'بالنجاح'],
#  ['نعم',
#   'مثل',
#   'الحثالة',
#   'الخا',
#   'نديم',
#   'قطيش',
#   'غيره',
#   'من',
#   'الامثال',
#   'الكل',
#   'يعرف',
#   'ان',
#   'شيعة',
#   'العالم',
#   'خاصة',
#   'في',
#   'هذه',
#   'الايام',
#   'انها',
#   'متحدة',
#   'اكثر',
#   'من',
#   'اي',
#   'وقت',
#   'مضى',
#   'وانها',
#   'باقية',
#   'تمد',
#   'باذن',
#   'اله',
#   'تعالى'],
#  ['الاشي',
#   'الوحيدالي',
#   'حزب',
#   'الشيطان',
#   'حقو',
#   'في',
#   'سورية',
#   'هو',
#   'انو',
#   'اعطا',
#   'المجموعات',
#   'الارهابية',
#   'سب',
#   'شرعية',
#   'لمهاجمة',
#   'لبنان'],
#  ['لن',
#   'تحصل',
#   'ال',
#   'مة',
#   'على',
#   'حق',
#   'من',
#   'حقوقها',
#   'داخليا',
#   'خارجيا',
#   'بمعزل',
#   'عن',
#   'الشرع',
#   'والجهاد',
#   'ولو',
#   'ظلت',
#   'تحاول',
#   'في',
#   'غير',
#   'هذا',
#   'الطريق',
#   'لاف',
#   'السنين',
#   'ما',
#   'وصلت',
#   'لشي'],
#  ['تذكر',
#   'الواقع',
#   'العربي',
#   'هل',
#   'دولة',
#   'جنوب',
#   'السودان',
#   'دولة',
#   'عربية'],
#  ['بفظل', 'نظام', 'البشير', 'المحتل', 'المجرم', 'بالسودانين'],
#  ['بل',
#   'خط',
#   'احمر',
#   'لاسرا',
#   'يل',
#   'سيدتك',
#   'وسيدة',
#   'ايران',
#   'والحكام',
#   'العرب',
#   'المنصبين',
#   'منها',
# ...
#   'وذل',
#   'يب',
#   'ون',
#   'في',
#   'الرقص',
#   'والتطبيل',
#   'والتزمير'],
#  ['تسلم',
#   'الواحد',
#   'من',
#   'دول',
#   'امه',
#   'تختار',
#   'له',
#   'زوجته',
#   'لا',
#   'يستطيع',
#   'التعليق',
#   'على',
#   'اي',
#   'فى',
#   'بلده',
#   'بعدين',
#   'يتكلم',
#   'على',
#   'مصر'],
#  ['الواحد',
#   'من',
#   'دول',
#   'امه',
#   'تختار',
#   'له',
#   'زوجته',
#   'لا',
#   'يستطيع',
#   'التعليق',
#   'على',
#   'اي',
#   'فى',
#   'بلده',
#   'بعدين',
#   'يتكلم',
#   'على',
#   'مصر',
#   'عن',
#   'الديمقراطية'],
#  ['منارة',
#   'ايه',
#   'وخرا',
#   'ايه',
#   'علي',
#   'دماغ',
#   'اهلك',
#   'انت',
#   'والي',
#   'زيك',
#   'رجعتونا',
#   'لعصر',
#   'الرملي',
#   'مش',
#   'الحجري',
#   'كمان',
#   'بجهلكم',
#   'الاعمي',
#   'حفاظكم',
#   'علي',
#   'مصالحكم'],
#  ['اول',
#   'جلسة',
#   'لبرلوان',
#   'سيكون',
#   'في',
#   'شارع',
#   'محمد',
#   'علي',
#   'وستر',
#   'سه',
#   'لام',
#   'المثالية'],
#  ['نا',
#   'اهتم',
#   'فقط',
#   'لدول',
#   'الشعوب',
#   'العربية',
#   'مصر',
#   'ما',
#   'تهمنيش',
#   'كلوا',
#   'تبن',
#   'او',
#   'كلوا',
#   'حشيش',
#   'يا',
#   'سلام',
#   'سلم',
#   'دا',
#   'شعب',
#   'جوعان',
#   'عريان',
#   'كرامة',
#   'يوك',
#   'ماليك'],
#  ['اتقو',
#   'اله',
#   'في',
#   'الجيل',
#   'القادم',
#   'فلسطين',
#   'احتلت',
#   'عام',
#   'وليس',
#   'وليس',
#   'هناك',
#   'دوله',
#   'اسمهاسرا',
#   'يل',
#   'حتي',
#   'لو',
#   'جمعت',
#   'الدنيا',
#   'باعترافهاو',
#   'خذلت',
#   'الجزيرة',
#   'محبيها'],
#  ['الهدف', 'المت', 'ثر', 'الوحيد', 'سوف', 'تكون', 'قطر'],
#  ['الحكاية',
#   'ان',
#   'هناك',
#   'دولة',
#   'تريد',
#   'مضايقة',
#   'العرب',
#   'وازعاج',
#   'قطر',
#   'في',
#   'استضافة',
#   'المونديال',
#   'فانفقت',
#   'المليارات',
#   'لاقصا',
#   'بلاتر',
#   'ولكن',
#   'خاب',
#   'الرز',
#   'وضاع'],
#  ['نعم',
#   'اقتربت',
#   'ساعةحكم',
#   'المستعمرين',
#   'واليهوذ',
#   'كهذالاسد',
#   'الصهيونى',
#   'اظحك',
#   'العالم',
#   'يوم',
#   'اخرج',
#   'الجيش',
#   'ليحارب',
#   'الشعب',
#   'السورى',
#   'وبثورة',
#   'علىاحتلاله',
#   'ويجب',
#   'الان',
#   'الاستعداد',
#   'لمحاكمته',
#   'والاقتصاص',
#   'منه',
#   'واجب',
#   'وشرع'],
#  ['البرهان',
#   'على',
#   'بقا',
#   'الاسد',
#   'ودحره',
#   'لمخط',
#   'الذي',
#   'مثليه',
#   'قطر',
#   'وسعود',
#   'واردوغان',
#   'لما',
#   'طارت',
#   'عبايات',
#   'الخليج',
#   'الى',
#   'واشنطون',
#   'وتس',
#   'اوباما',
#   'شو',
#   'العمل',
#   'يا',
#   'رجال',
#   'الدور',
#   'ال',
#   'تركيا',
#   'والسعوديه',
#   'ابشروا'],
#  ['واله',
#   'كلامك',
#   'مظبوط',
#   'وانا',
#   'اسمع',
#   'عن',
#   'اليمن',
#   'واعد',
#   'اعداد',
#   'القتلى',
#   'من',
#   'الحوثين',
#   'وانصار',
#   'صالح',
#   'اليوم',
#   'اصبح',
#   'عدهم',
#   'ولم',
#   'يقتل',
#   'من',
#   'الطرف',
#   'الاخر',
#   'الا',
#   'فردا',
#   'واله',
#   'نكته',
#   'دى'],
#  ['تغيرت',
#   'شيا',
#   'كثيره',
#   'كلاب',
#   'الحكم',
#   'المستعره',
#   'كالنعجه',
#   'سد',
#   'السوسي',
#   'صحاب',
#   'المعالي',
#   'السمو',
#   'كلهم',
#   'يمكنهم',
#   'يظلوا',
#   'حتى',
#   'ما',
#   'يستطيعوا',
#   'ستقرار',
#   'الغربين',
#   'وروبا',
#   'روسبا',
#   'لا',
#   'يستحمل',
#   'تغيرات',
#   'جوهريه',
#   'في',
#   'الشرق',
#   'وسط'],
#  ['لا', 'نها', 'نظام', 'سعود', 'ثان', 'السعود', 'قطر', 'قر', 'جدا'],
#  ['لو',
#   'استطاعوا',
#   'ان',
#   'يعدموه',
#   'لاعدموه',
#   'ولكن',
#   'هو',
#   'اسد',
#   'وهم',
#   'بعير',
#   'وهل',
#   'يقترب',
#   'البعير',
#   'من',
#   'الاسد'],
#  ['لم', 'ارى', 'نذل', 'قذر', 'من', 'هذا', 'القضا'],
#  ['الحل', 'الوحيد', 'هو', 'اعلان', 'الحرب', 'ضد', 'هذا', 'الكافر', 'السيسي'],
#  ['لقد', 'ارسلت', 'تعليقي', 'مند', 'ربع', 'ساعات', 'لم', 'ينشر'],
#  ['سياسي',
#   'بامتياز',
#   'خرج',
#   'من',
#   'دا',
#   'رة',
#   'السيسي',
#   'وكلابه',
#   'وتلاه',
#   'القاضي',
#   'النابح',
#   'بما',
#   'يمليه',
#   'عليه',
#   'الانقلابيون'],
#  ['الحكم', 'سياسي'],
#  ['حكم',
#   'جا',
#   'من',
#   'تلافيف',
#   'وليس',
#   'من',
#   'نطام',
#   'السيسي',
#   'هو',
#   'ليس',
#   'بيده',
#   'شي'],
#  ['حكم', 'ابن', 'حرام'],
#  ['هذا',
#   'السيسي',
#   'لا',
#   'احسبه',
#   'مسلما',
#   'غير',
#   'الحكم',
#   'وقتل',
#   'الناس',
#   'في',
#   'المساجد',
#   'والشوارع',
#   'بل',
#   'احرق',
#   'مساجد',
#   'اله',
#   'وحتي',
#   'احرق',
#   'كتب',
#   'الاسلام',
#   'منع',
#   'تدريسه',
#   'في',
#   'المدارس',
#   'ما',
#   'تنتظرون',
#   'ياهل',
#   'مصر',
#   'بعد',
#   'ان',
#   'كنتم',
#   'منارة',
#   'القران'],
#  ['ولماذا', 'لم', 'تحترم', 'حق', 'الشعب', 'في', 'ختيار', 'الر', 'يس', 'مرسي'],
#  ['صدقت',
#   'اصبح',
#   'الاخوان',
#   'السعودين',
#   'يفضلون',
#   'اردوغان',
#   'علي',
#   'ملكهم',
#   'وفي',
#   'ظل',
#   'احلام',
#   'السلطنه',
#   'سوف',
#   'يقسم',
#   'كل',
#   'الدول',
#   'المجاوره',
#   'له',
#   'بمساعده',
#   'اهلها'],
#  ['الموت', 'لعرب', 'الخنزير'],
#  ['نظام',
#   'الكفتة',
#   'في',
#   'مصر',
#   'منبوذ',
#   'من',
#   'شعب',
#   'مصر',
#   'العظيم',
#   'ومن',
#   'العرب',
#   'الشرفا',
#   'ومن',
#   'العالم',
#   'ال',
#   'سلامي',
#   'صدقا',
#   'سرا',
#   'يل',
#   'والصهيونية',
#   'العالمية',
#   'التي',
#   'جا',
#   'به',
#   'يران',
#   'ولا',
#   'خال',
#   'المحامي',
#   'فندي',
#   'لا',
#   'محامي',
#   'كفتة'],
#  ['اعز', 'اله', 'تركياو', 'ذل', 'اله', 'السيسي', 'ونظامه', 'واعلامه'],
#  ['انه',
#   'اوردغان',
#   'الرجل',
#   'الم',
#   'من',
#   'المخلص',
#   'انه',
#   'ليس',
#   'السيس',
#   'ويا',
#   'اخي',
#   'هداك',
#   'اله',
#   'هذه',
#   'تركيا',
#   'وليست',
#   'مصر',
#   'وهذه',
#   'انتخابات',
#   'وليست',
#   'انقلاب',
#   'وهذا',
#   'خكم',
#   'الشعب',
#   'وليس',
#   'حكم',
#   'العسكر'],
#  ['بل',
#   'نقذف',
#   'بالحق',
#   'على',
#   'الباطل',
#   'فيدمغه',
#   'ذا',
#   'هو',
#   'زاهق',
#   'ولكم',
#   'الويل',
#   'ما',
#   'تصفون'],
#  ['الاعراب', 'اشد', 'كفرا', 'ونفاقا'],
#  ['عجيبة',
#   'فلاح',
#   'يقرا',
#   'اخبار',
#   'الاقتصاد',
#   'ويقوم',
#   'بالتعليق',
#   'عليها',
#   'ربما',
#   'اكثرت',
#   'من',
#   'شرب',
#   'الحليب',
#   'الدسم'],
#  ['لا',
#   'نا',
#   'لست',
#   'خا',
#   'فا',
#   'عرف',
#   'هناك',
#   'تغيرا',
#   'قادم',
#   'خذت',
#   'التدابير',
#   'الازمة',
#   'في',
#   'الواقع',
#   'المال',
#   'لا',
#   'قيمة',
#   'له',
#   'نت',
#   'بحاجة',
#   'لحراسته',
#   'لكن',
#   'المعرفة',
#   'تحرسك',
#   'لهذا',
#   'السب',
#   'غلى',
#   'ما',
#   'في',
#   'ليبيا',
#   'قطر',
#   'الشعب'],
#  ['بكون',
#   'فرحان',
#   'جدا',
#   'مع',
#   'كل',
#   'خسارة',
#   'لبورصة',
#   'وخصوصا',
#   'المصرية',
#   'لان',
#   'كلها',
#   'نصب',
#   'وغش',
#   'يارب',
#   'البورصة',
#   'تقع',
#   'وما',
#   'تقملهاش',
#   'قومة',
#   'تاني'],
#  ['لا', 'دري', 'لماذا', 'شعر', 'ال', 'مر', 'لا', 'يهمني'],
#  ['اخرس',
#   'انت',
#   'تكذب',
#   'وكلامك',
#   'فيه',
#   'نبرة',
#   'الحقد',
#   'والسم',
#   'تنضح',
#   'من',
#   'كلامك',
#   'واله',
#   'انت',
#   'وجماعتك',
#   'مفتاح',
#   'اليهود',
#   'في',
#   'تركيا',
#   'والعراق',
#   'وسوريا',
#   'وكل',
#   'بلد',
#   'اسلامي'],
#  ['هدف',
#   'حزب',
#   'الاكراد',
#   'هو',
#   'اقصا',
#   'اردوغان',
#   'فقط',
#   'لا',
#   'غير',
#   'لكن',
#   'ما',
#   'فعلوة',
#   'هو',
#   'اكبر',
#   'لان',
#   'العملية',
#   'السلمية',
#   'منذ',
#   'الان',
#   'في',
#   'حكم',
#   'المنتهية'],
#  ['هذا', 'هو', 'الغبا', 'الصحفي', 'عندما', 'يصبح', 'مريكا', 'مبادي'],
#  ['الم',
#   'يقل',
#   'سيدهم',
#   'حسين',
#   'كل',
#   'بلية',
#   'اصيبت',
#   'بها',
#   'هذة',
#   'الامة',
#   'سبها',
#   'عمر',
#   'وكذلك',
#   'فان',
#   'كل',
#   'بلية',
#   'حلت',
#   'بالشعب',
#   'اليمني',
#   'سبها',
#   'الحوثي',
#   'وايران'],
#  ['ايران', 'مافيه', 'هنا', 'هرون', 'بنيعش', 'اليمن'],
#  ['الشيعة',
#   'متل',
#   'لسلطان',
#   'ما',
#   'بيخروب',
#   'حالو',
#   'والجسم',
#   'كلو',
#   'ازا',
#   'دخل',
#   'والغريب',
#   'السلطان',
#   'لمرض',
#   'بعدما',
#   'بيدمر',
#   'لجسم',
#   'بس',
#   'يقتلو',
#   'بيندفن',
#   'معو',
#   'فنحن',
#   'منسطصلو',
#   'من',
#   'لجسم',
#   'حتا',
#   'لو',
#   'سب',
#   'ضرار',
#   'بلجسم',
#   'بس',
#   'منعيش',
#   'عجز',
#   'احلما',
#   'نموت',
#   'ومع',
#   'لاسف'],
#  ['نعم',
#   'مشاركه',
#   'وهيا',
#   'وتشارك',
#   'في',
#   'دمار',
#   'اليمن',
#   'من',
#   'يرظي',
#   'في',
#   'دمار',
#   'بلده',
#   'هل',
#   'اليمني',
#   'يدمر',
#   'بلده',
#   'الشعب',
#   'اليمني',
#   'شعب',
#   'طيب',
#   'القلب',
#   'متجي',
#   'له',
#   'مثل',
#   'هذي',
#   'ال',
#   'شيا'],
#  ['ايران',
#   'تدخل',
#   'تصدر',
#   'عقيتدتها',
#   'الجوفا',
#   'الى',
#   'الضعفا',
#   'مثل',
#   'العراق',
#   'وسوريا',
#   'ولبنان',
#   'واليمن',
#   'وهي',
#   'دول',
#   'لاتملك',
#   'مقومات',
#   'القوه',
#   'وتنتشر',
#   'فيها',
#   'الحروب',
#   'نتيجه',
#   'لطاعون',
#   'العصبيه',
#   'والقبليه',
#   'والدكتاتوريه'],
#  ['الس',
#   'ال',
#   'خط',
#   'السعود',
#   'تقصف',
#   'الشعب',
#   'ال',
#   'مني',
#   'بدعم',
#   'سرا',
#   'نت',
#   'تس',
#   'عن',
#   'دور',
#   'ران',
#   'حزب',
#   'اله'],
#  ['ايران',
#   'عاه',
#   'ره',
#   'قد',
#   'اغوت',
#   'من',
#   'هم',
#   'على',
#   'نفس',
#   'شاكلتها',
#   'مثل',
#   'حسن',
#   'زميرة',
#   'عبد',
#   'الحوثي',
#   'من',
#   'سي',
#   'الدين',
#   'الخلق'],
#  ['لم',
#   'تنشروا',
#   'خبر',
#   'قيام',
#   'نظام',
#   'الاجرام',
#   'في',
#   'مصر',
#   'بتعذيب',
#   'وقتل',
#   'عماد',
#   'المرزوقي',
#   'شقيق',
#   'الناشط',
#   'السيناوي',
#   'عيد',
#   'المرزوقي'],
#  ['حرامى',
#   'شال',
#   'حرامى',
#   'وجاب',
#   'حرامى',
#   'ال',
#   'غريب',
#   'ما',
#   'اجاوبش',
#   'عاليه'],
#  ['تغير',
#   'او',
#   'تحصين',
#   'وك',
#   'الاحتلال',
#   'هكذا',
#   'سيتغير',
#   'لوحده',
#   'ولا',
#   'مثل',
#   'لشعوبنالعربيةعلى',
#   'الارض',
#   'كلها',
#   'وقابلةلاحتلال',
#   'والاستعمار',
#   'ينكره',
#   'الا',
#   'الجاحد',
#   'بل',
#   'اخاف',
#   'ان',
#   'لا',
#   'تعش',
#   'الا',
#   'به'],
#  ['هذه', 'تجربة'],
#  ['ند',
#   'ند',
#   'ند',
#   'التنديد',
#   'كعكة',
#   'لتايد',
#   'فقط',
#   'لتلجيم',
#   'الشعوب',
#   'لا',
#   'غير',
#   'انا',
#   'له',
#   'انا',
#   'اليه',
#   'راجعون'],
#  ['هكذا'],
#  ['هجوم',
#   'سافر',
#   'وقح',
#   'وهيمنه',
#   'وجبروت',
#   'واستعراض',
#   'قوة',
#   'غير',
#   'مبرويجب',
#   'محاكمه',
#   'المس',
#   'ولين',
#   'فى',
#   'محكمه',
#   'الجنا',
#   'يه',
#   'الدوليه',
#   'وفرض',
#   'عقوبات',
#   'دوليه',
#   'ومقاطعات',
#   'سياسيه',
#   'ودبلوماسيهواقتصاديه'],
#  ['السلام',
#   'عليكم',
#   'انا',
#   'مابغ',
#   'كم',
#   'تطلعون',
#   'الرس',
#   'لة',
#   'بس',
#   'رسلو',
#   'لي',
#   'على',
#   'ال',
#   'يميل',
#   'كيف',
#   'رك',
#   'سطول',
#   'الحرية',
#   'ني',
#   'ماشفت',
#   'اي',
#   'اعلان',
#   'وحاولت',
#   'ابحث',
#   'عن',
#   'العنو',
#   'لقيت',
#   'رة',
#   'من',
#   'السعودية'],
#  ['لماذا',
#   'لا',
#   'تس',
#   'الجزيرة',
#   'كيف',
#   'نظر',
#   'لصت',
#   'شيوخ',
#   'الوهابية',
#   'على',
#   'لا',
#   'الاج',
#   'ين'],
#  ['لماذا',
#   'لا',
#   'تس',
#   'الجزيرة',
#   'عن',
#   'صمت',
#   'شيوخ',
#   'الوهابية',
#   'على',
#   'لا',
#   'الاج',
#   'ين'],
#  ['لماذا',
#   'لا',
#   'تس',
#   'الجزيرة',
#   'عن',
#   'سب',
#   'صمت',
#   'شيوخ',
#   'الوهابية',
#   'على',
#   'لا',
#   'الاج',
#   'ين'],
#  ['ومتى', 'ينسحب', 'الامريكيون', 'من', 'الوطن', 'العربى'],
#  ['السوال',
#   'من',
#   'ينفع',
#   'من',
#   'اختلاف',
#   'بين',
#   'المسلمين',
#   'العراق',
#   'جواب',
#   'امري'],
#  ['بل', 'بلطجة'],
#  ['عدم',
#   'عتقال',
#   'السيسى',
#   'رغم',
#   'تقارير',
#   'منظمات',
#   'حقوق',
#   'ال',
#   'نسان',
#   'يفضح',
#   'لمانيا'],
#  ['عار',
#   'على',
#   'دولة',
#   'ديمقراطية',
#   'مثل',
#   'الماني',
#   'ان',
#   'تنفذ',
#   'امر',
#   'القا',
#   'قبض',
#   'على',
#   'صحافى',
#   'وهى',
#   'تعلم',
#   'تماما',
#   'انه',
#   'صحافي',
#   'لا',
#   'لش',
#   'الا',
#   'ان',
#   'دكتاتور',
#   'ما',
#   'طلب',
#   'ذلك'],
#  ['عجبت',
#   'لمن',
#   'ينصح',
#   'اوروبا',
#   'حترام',
#   'حقوق',
#   'الانسان',
#   'يانبيل',
#   'عبدالقادر',
#   'بك',
#   'خل',
#   'يحتاج',
#   'صلاح'],
#  ['ليس',
#   'في',
#   'الموت',
#   'شماته',
#   'ولكن',
#   'الا',
#   'يموت',
#   'من',
#   'المسلمين',
#   'كل',
#   'يوم',
#   'الالاف',
#   'وهم',
#   'الغرب',
#   'لا',
#   'يكترثون',
#   'رغم',
#   'كونها',
#   'صنيعتهم',
#   'ليذوقو',
#   'جز',
#   'من',
#   'ويلات',
#   'ما',
#   'يصنعوه'],
#  ['دوله',
#   'تر',
#   'است',
#   'عل',
#   'معاداه',
#   'الاسلام',
#   'علنا',
#   'فلهذا',
#   'هذه',
#   'الدوله',
#   'ست',
#   'منصوره',
#   'لان',
#   'اولها',
#   'حرب',
#   'عل',
#   'اله',
#   'الرسول',
#   'سلم',
#   'هود',
#   'الماسون',
#   'العالم'],
#  ['اعتقد',
#   'ان',
#   'تلك',
#   'الصور',
#   'المعلومات',
#   'التي',
#   'كشف',
#   'عنها',
#   'حزب',
#   'اله',
#   'ماكانت',
#   'لتضهر',
#   'لولى',
#   'الاتهام',
#   'الموجه',
#   'لعناصر',
#   'من',
#   'حزب',
#   'اله'],
#  ['ليس',
#   'حبا',
#   'في',
#   'سرا',
#   'يل',
#   'فنحن',
#   'نبغضها',
#   'نها',
#   'احتلت',
#   'رضنا',
#   'لما',
#   'قامت',
#   'به',
#   'في',
#   'حق',
#   'خوانا',
#   'لكن',
#   'تسعة',
#   'عشار',
#   'دين',
#   'الرافضة',
#   'يقوم',
#   'على',
#   'الكذب',
#   'لا',
#   'ين',
#   'هذه',
#   'القرا',
#   'منذ',
#   'سنوات',
#   'لماذا',
#   'خرجت',
#   'ال'],
#  ['اتعجب',
#   'كثيرا',
#   'من',
#   'الذين',
#   'يقولون',
#   'اين',
#   'حزب',
#   'اله',
#   'عن',
#   'غزة',
#   'ولا',
#   'يقولون',
#   'اين',
#   'العرب',
#   'يا',
#   'اخي',
#   'انت',
#   'ماعندك',
#   'شي',
#   'تنتقد',
#   'فيه',
#   'حزب',
#   'اله'],
#  ['قل',
#   'الحمد',
#   'له',
#   'الذى',
#   'قضى',
#   'شعب',
#   'مصر',
#   'على',
#   'حكم',
#   'المتاسلمين'],
#  ['الويل', 'لكم', 'يا', 'عرب', 'ويا', 'مسلمين'],
#  ['التحالف',
#   'الصليبي',
#   'احتل',
#   'وشرذم',
#   'العراق',
#   'بماسعدة',
#   'خد',
#   'ام',
#   'الحرمين',
#   'ودخل',
#   'العراق',
#   'من',
#   'اراضي',
#   'التي',
#   'تحكمها',
#   'الشريعة',
#   'الاسلامية',
#   'اعطينا',
#   'شي',
#   'جديد',
#   'لكي',
#   'نتداوله'],
#  ['على',
#   'القبا',
#   'المحتلة',
#   'لطا',
#   'من',
#   'لحوج',
#   'اليمن',
#   'رهابين',
#   'نجد',
#   'رهابين',
#   'قريش',
#   'الخروج',
#   'منها',
#   'كما',
#   'دخلوها',
#   'بالاحتلال',
#   'سيخرجون',
#   'منها',
#   'بالاحتلال',
#   'الطا',
#   'لهوازن',
#   'ثقيف',
#   'فقط'],
#  ['الغايه',
#   'تبر',
#   'الوسيله',
#   'هو',
#   'الشعار',
#   'المشترك',
#   'لاسلام',
#   'السياسي',
#   'المعارضين',
#   'كفار',
#   'دمهم',
#   'حلال',
#   'البغدادي',
#   'اردوغان',
#   'وجهان',
#   'لعمله',
#   'واحده'],
#  ['الى', 'سقوط', 'طا', 'رة', 'ثانية', 'ان', 'شا', 'اله'],
#  ['يعني', 'الامارات', 'متهمة', 'عشان', 'ما', 'تفقد', 'مكانتها'],
#  ['رقم',
#   'ثلاثة',
#   'ليش',
#   'محروق',
#   'البك',
#   'من',
#   'لبنان',
#   'لبنان',
#   'بلد',
#   'متخلف',
#   'ليك',
#   'مين',
#   'عم',
#   'يحكي',
#   'اردني',
#   'متطور',
#   'لما',
#   'لبنان',
#   'كان',
#   'في',
#   'جامعات',
#   'مستشفيات',
#   'ومثقفين',
#   'انتو',
#   'كنتو',
#   'بعدكن',
#   'بالشوادر',
#   'روح',
#   'اغسل',
#   'وجهك',
#   'بالبحر'],
#  ['يا',
#   'لبناني',
#   'يا',
#   'مغترب',
#   'في',
#   'انغولا',
#   'واله',
#   'الكثير',
#   'من',
#   'الشباب',
#   'الفلسطينين',
#   'في',
#   'لبنان',
#   'يدفعون',
#   'مبالغ',
#   'تراوح',
#   'ما',
#   'بين',
#   'دولار',
#   'لسفر',
#   'بطرق',
#   'غير',
#   'شرعيه',
#   'خطرة',
#   'فقط',
#   'لهروب',
#   'من',
#   'قباحة',
#   'لبنان',
#   'الى',
#   'بلد',
#   'محترم'],
#  ['والة',
#   'اذا',
#   'البنانيون',
#   'اذا',
#   'سحقو',
#   'ومسحو',
#   'حق',
#   'الفلسطيني',
#   'في',
#   'لبنان',
#   'وهذا',
#   'الامر',
#   'موجود',
#   'اصلا',
#   'برا',
#   'فلا',
#   'مشكلة',
#   'في',
#   'ذالك',
#   'لا',
#   'البنانيون',
#   'بل',
#   'كل',
#   'لبناني',
#   'بشخصة',
#   'يكرة',
#   'نفسة',
#   'فكيف',
#   'يحب',
#   'ما',
#   'لة',
#   'لغيرة'],
#  ['عيب',
#   'يا',
#   'عون',
#   'بيكفي',
#   'طا',
#   'فية',
#   'شوف',
#   'الحكيم',
#   'شو',
#   'عمل',
#   'تعلم'],
#  ['لا', 'حول', 'ولا', 'قوة', 'الا', 'باله'],
#  ['غريب',
#   'اقوى',
#   'قناة',
#   'اعلامية',
#   'في',
#   'الوطن',
#   'العربي',
#   'تسال',
#   'الجمهور',
#   'شو',
#   'لازم',
#   'نعمل',
#   'قسما',
#   'باله',
#   'مصيبتنا',
#   'لم',
#   'يخلق',
#   'اله',
#   'مثلها',
#   'ابدا'],
#  ['فقط',
#   'اتركو',
#   'دولة',
#   'الخلافة',
#   'ولا',
#   'تحاربوها',
#   'لمدة',
#   'عوام',
#   'وعهد',
#   'في',
#   'رقابنا',
#   'وعلى',
#   'دما',
#   'نا',
#   'ودما',
#   'اطفالنا',
#   'سيكون',
#   'الاقصى',
#   'بين',
#   'يدينا',
#   'بالسنة',
#   'السادسة',
#   'ذن',
#   'اله'],
#  ['نشا',
#   'اله',
#   'نهايتكم',
#   'سوف',
#   'تكون',
#   'بشع',
#   'من',
#   'ما',
#   'حصل',
#   'وروبا',
#   'يا',
#   'ابن',
#   'اليهودية',
#   'والزمن',
#   'بينا'],
#  ['يا',
#   'الجزيرة',
#   'لونا',
#   'لة',
#   'سهله',
#   'وبسيطة',
#   'شا',
#   'اله',
#   'سنتعلم',
#   'ونتطور',
#   'وسنجاوب',
#   'مثل',
#   'هذه',
#   'ال',
#   'لة',
#   'الصعبه',
#   'شا',
#   'اله',
#   'قريب'],
#  ['عجلوا',
#   'في',
#   'سقوط',
#   'بشار',
#   'الاسود',
#   'حتى',
#   'يتفرغ',
#   'جند',
#   'الشام',
#   'في',
#   'تحرير',
#   'الاقصى',
#   'فمادام',
#   'الاقصى',
#   'اسيرا',
#   'عن',
#   'اليهود',
#   'فسوف',
#   'يتفنون',
#   'في',
#   'اذلاله',
#   'وهدمه'],
#  ['سنطنطنطن',
#   'الاذاعه',
#   'المحليه',
#   'مش',
#   'تعرف',
#   'تكتب',
#   'عربي',
#   'اول',
#   'يا',
#   'فهيم',
#   'خيبر',
#   'وحضرتك',
#   'من',
#   'وين',
#   'بلا',
#   'زغره',
#   'هندي',
#   'قردي',
#   'والا',
#   'من',
#   'جماعه',
#   'طبلوا',
#   'والا',
#   'من',
#   'ربع',
#   'وجه',
#   'العنز'],
#  ['يجب',
#   'على',
#   'الذين',
#   'يدعون',
#   'نفسهم',
#   'نهم',
#   'عرب',
#   'يقر',
#   'تاريخ',
#   'العرب',
#   'الحقيقيون',
#   'فنحن',
#   'عرب',
#   'مع',
#   'مزيج',
#   'صهيوني',
#   'يهودي'],
#  ['المطلوب',
#   'هو',
#   'استقبال',
#   'وتعويض',
#   'المهاجرين',
#   'الفلسطينين',
#   'بحياة',
#   'كريمة',
#   'سلامة',
#   'المسلمين',
#   'وحرية',
#   'العبادة',
#   'هم',
#   'من',
#   'العراك',
#   'السخيف',
#   'على',
#   'قطعة',
#   'رض',
#   'ميته'],
#  ['بعـد',
#   'من',
#   'قومية',
#   'لاف',
#   'السنين',
#   'ما',
#   'يعدون',
#   'قول',
#   'بشر',
#   'ليس',
#   'وحيا',
#   'قسما',
#   'بربه',
#   'ال',
#   'على'],
#  ['فناه',
#   'الجزيره',
#   'تهتم',
#   'بالفتن',
#   'اكثر',
#   'من',
#   'المصادقيه',
#   'وكل',
#   'من',
#   'يدفع',
#   'اكثر',
#   'تروج',
#   'له',
#   'اكثر',
#   'وهي',
#   'اسو',
#   'قناه',
#   'اخباريه',
#   'عربيه',
#   'او',
#   'بالصح',
#   'القناه',
#   'العبريه'],
#  ['يبدوا',
#   'انك',
#   'من',
#   'الفلول',
#   'ومن',
#   'انصار',
#   'القاتل',
#   'السيسي',
#   'عليه',
#   'ما',
#   'يستحق',
#   'من',
#   'غضب',
#   'اله'],
#  ['زغردي',
#   'يا',
#   'انشراح',
#   'مرسي',
#   'خد',
#   'عدام',
#   'مبارك',
#   'تمام',
#   'السيسي',
#   'قلوا',
#   'لعدل',
#   'نام',
#   'عاوزين',
#   'نام',
#   'زغرودة',
#   'مصرية',
#   'من',
#   'فيفي',
#   'ال',
#   'المثالية',
#   'يحيا',
#   'العدل'],
#  ['كل', 'بلد', 'تخليها', 'فى', 'حالها', 'كل', 'بلد', 'فيها', 'الى', 'مكفيها'],
#  ...]

# %%
def text_to_vector(text):
    vector = []
    for word in text.split():
        if word in embedding_model.wv:
            vector.append(embedding_model.wv[word])
    if vector:
        vector = np.mean(vector, axis=0)
    else:
        vector = np.zeros(embedding_model.vector_size)
    return vector

df['Vector'] = df['Text'].apply(text_to_vector)

# %%
text = df['Text'][1]
vector = text_to_vector(text)
print("Text:", text)
print("Vector:", vector)
# Out:
# Text: مريكا قتلت بالامس معوق رفض رفع يديه فماذا تريد من الشرطة المصرية تفعل عندما تعامل مع مسلحين معهم متفجرات
# Vector: [-0.36112776  0.30494243  0.24558525 -0.4735253   0.24384551 -0.3850021
#   0.2506579   1.0850585   0.13199401 -0.01537475 -0.02701964 -1.0646343
#  -0.2907199   0.26681003  0.0011454  -0.5830876   0.1603785  -0.18098271
#  -0.15568072 -0.74646485 -0.00845524 -0.09191674  0.53472453 -0.52977324
#   0.20772298 -0.0582713  -0.4002066  -0.39734614 -0.34492794  0.27451724
#   0.62213135 -0.07906406 -0.11100897 -0.49478194 -0.16031073  0.14285915
#   0.17543772 -0.04585664 -0.16069268 -0.67187226  0.723916   -0.5203179
#  -0.56017286  0.2660966   0.46549296 -0.23078915  0.05115719  0.08693587
#  -0.27859375  0.3943416   0.4321132  -0.7685168   0.03478753 -0.38199148
#  -0.40422627  0.34009734  0.4178826  -0.23654373 -0.15537012  0.07007518
#  -0.20095162 -0.39382875  0.398158   -0.13022335 -0.33680424  0.58813936
#   0.40047592  0.23796111 -0.4905924   0.46194935 -0.3342154  -0.0229991
#   0.6700082   0.366135    0.22751537  0.17804162  0.11343076 -0.23936261
#  -0.48840332  0.19389772 -0.40280995  0.14937289  0.13223748  0.18812509
#   0.11646964 -0.12649877  0.42864403  0.36847085  0.5122186   0.3397115
#   0.61455274 -0.06365775  0.24165216 -0.38985893  0.70568943  0.78354275
#   0.45089304 -0.20301713 -0.0250103  -0.28659096]

# %%
df.to_csv('embedding_data.csv', index=False)

# %% [markdown]
# <h1> Partition Data

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Vector'].tolist(), df['Toxic/Not Toxic'].tolist(), test_size=0.2, random_state=42)

# %%
print(X_train[1])
# Out:
# [-0.09882917  0.12290701  0.07927855 -0.01784953  0.10019874 -0.13530946
#   0.10500646  0.3393027   0.01759651 -0.05283675  0.00079866 -0.28933075
#  -0.0807373   0.17062628  0.03240484 -0.09046509  0.08753683 -0.10240202
#  -0.02318178 -0.25394845  0.00597633  0.05677351  0.1427609  -0.10832693
#   0.02863271 -0.0096206  -0.12273762 -0.01675454 -0.12643234  0.11820293
#   0.17366764 -0.0247314  -0.01447842 -0.16735727 -0.1181251   0.15087266
#   0.03963425 -0.00832015 -0.10914602 -0.14370403  0.21668334 -0.13318741
#  -0.1595377   0.03824209  0.13278395 -0.05557355 -0.00403527 -0.03316787
#  -0.05256922  0.13450602  0.05651772 -0.22990818 -0.01538523 -0.14299265
#  -0.08776884  0.06657483  0.11881943 -0.04296436 -0.03161937  0.0153317
#  -0.08293361 -0.02401959  0.12012056 -0.00859915 -0.12334124  0.16739175
#   0.09090238  0.11225545 -0.17447922  0.1667651  -0.04247602  0.05911997
#   0.22198603  0.07507807  0.09389732  0.06511833  0.00286643 -0.07319652
#  -0.15253109  0.04514971 -0.06322123 -0.05383851  0.05049839  0.10180965
#  -0.07370724 -0.02828133  0.12322858  0.04163314  0.14760664  0.09844869
#   0.2076152  -0.03094502  0.0796999  -0.01672741  0.19472095  0.21196562
#   0.14261107 -0.06925984 -0.00482329 -0.05873644]

# %% [markdown]
# <h1> SVM

# %%
svm_model = SVC(verbose=1)
svm_model.fit(X_train, y_train)
# Out:
# [LibSVM]
# SVC(verbose=1)

# %%
y_preds = svm_model.predict(X_test)

# %%
svm_scores = svm_model.decision_function(X_test)

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_preds)
precision = precision_score(y_test, y_preds)
recall = recall_score(y_test, y_preds)
f1 = f1_score(y_test, y_preds)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.6811350090697071
# Precision: 0.6778618732261117
# Recall: 0.8252706749596868
# F1 Score: 0.7443382505713693

# %%
import joblib

# Enregistrement du modèle
joblib.dump(svm_model, 'svc_model.pkl')
# Out:
# ['svc_model.pkl']

# %% [markdown]
# <h1> RandomForest

# %%
# Random Forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

rf_pred_prob = rf.predict_proba(X_test)[:,1]

# %%
y_predf = rf.predict(X_test)

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_predf)
precision = precision_score(y_test, y_predf)
recall = recall_score(y_test, y_predf)
f1 = f1_score(y_test, y_predf)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7129437678154963
# Precision: 0.7211528456976382
# Recall: 0.7983183598249252
# F1 Score: 0.757776198545892

# %%
import joblib

# Enregistrement du modèle
joblib.dump(rf, 'rf_model.pkl')
# Out:
# ['rf_model.pkl']

# %% [markdown]
# <h1> Naive Bayes

# %%
# Naive Bayes
nb = GaussianNB()
nb.fit(X_train, y_train)
nb_pred_prob = nb.predict_proba(X_test)[:,1]

# %%
y_predn = nb.predict(X_test)

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_predn)
precision = precision_score(y_test, y_predn)
recall = recall_score(y_test, y_predn)
f1 = f1_score(y_test, y_predn)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.6133065561026173
# Precision: 0.6201612188856409
# Recall: 0.8063810181985718
# F1 Score: 0.7011166190976916

# %%
import joblib

# Enregistrement du modèle
joblib.dump(nb, 'nb_model.pkl')
# Out:
# ['nb_model.pkl']

# %% [markdown]
# <h1>graph

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Compute the False Positive Rate (fpr) and True Positive Rate (tpr) for each classifier
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_pred_prob)
fpr_svm, tpr_svm, _ = roc_curve(y_test, svm_scores)
fpr_nb, tpr_nb, _ = roc_curve(y_test, nb_pred_prob)  # Add Naive Bayes fpr and tpr

# Compute the Area Under Curve (AUC) for each classifier
roc_auc_rf = auc(fpr_rf, tpr_rf)
roc_auc_svm = auc(fpr_svm, tpr_svm)
roc_auc_nb = auc(fpr_nb, tpr_nb)  # Calculate Naive Bayes AUC

# Plot the ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_rf, tpr_rf, color='b', label=f'Random Forest + WE (AUC = {roc_auc_rf:.2f})')
plt.plot(fpr_svm, tpr_svm, color='g', label=f'SVM + WE (AUC = {roc_auc_svm:.2f})')
plt.plot(fpr_nb, tpr_nb, color='orange', label=f'Naive Bayes + WE (AUC = {roc_auc_nb:.2f})')  # Add Naive Bayes to the plot
plt.plot([0, 1], [0, 1], color='r', linestyle='--', label='Random')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <h1>Test

# %%
# Créer la dataframe avec une seule colonne nommée "Text"
Text1 = "حمارة"

Vector1 = text_to_vector(Text1)
print("Text1:", Text1)
print("Vector1:", Vector1)
Vector1 = Vector1.reshape(1, -1)

y1_predf = rf.predict(Vector1)
print(y1_predf)

y3_preds = svm_model.predict(Vector1)
print(y3_preds)

y4_pred = nb.predict(Vector1)
print(y4_pred)
# Out:
# Text1: حمارة
# Vector1: [-0.14973335  0.27937302  0.173326    0.06335063  0.28898397 -0.18533576
#   0.16484906  0.5778371   0.0417579  -0.20891258 -0.00276609 -0.5513064
#  -0.06605551  0.34616688  0.06521963 -0.1399599   0.21855831 -0.18367483
#  -0.05237097 -0.40123662  0.02686944  0.152404    0.18436636 -0.14662068
#   0.01464185 -0.00133669 -0.20430386 -0.03620192 -0.20337725  0.12012904
#   0.2384703  -0.09155199 -0.06529714 -0.31350765 -0.14505193  0.34041578
#   0.14252253  0.02628486 -0.24843785 -0.2246633   0.2975564  -0.24473187
#  -0.3636355  -0.00180379  0.16782172 -0.0862137  -0.01832524 -0.12746349
#  -0.15887056  0.24724707  0.02083155 -0.46724346 -0.0828472  -0.25714663
#  -0.19924541  0.13874595  0.3125754  -0.10289153 -0.04760206 -0.01472891
#  -0.21915561  0.0486096   0.24671791 -0.0268305  -0.25834274  0.2772142
#   0.09554273  0.20843686 -0.31005496  0.21597461 -0.05435853  0.13889569
#   0.43520454  0.16488262  0.20220082  0.06374081  0.02643288 -0.14246902
#  -0.31455073  0.05804389 -0.20155172 -0.10875189  0.14734699  0.17256714
#  -0.08395404 -0.05306363  0.24827975  0.04334351  0.21239139  0.13449845
#   0.3214679  -0.02692789  0.10213845  0.07886377  0.36109313  0.36365354
#   0.27474988 -0.15506719 -0.0354426  -0.01976832]
# [1]
# [1]
# [1]

# %% [markdown]
# <h1> Transformers

# %%
from transformers import AutoTokenizer, AutoModel

# %%
tokenizer = AutoTokenizer.from_pretrained('aubmindlab/bert-base-arabertv02')
model = AutoModel.from_pretrained('aubmindlab/bert-base-arabertv02')
# Out:
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv02 were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import torch

def extract_features(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    outputs = model(**inputs)
    # Use the mean of the last hidden state as a sentence representation
    sentence_representation = torch.mean(outputs.last_hidden_state[0], dim=0)
    return sentence_representation.detach().numpy()

df['Text'] = df['Text'].apply(lambda x: str(x) if pd.notnull(x) else '')


# Apply the feature extraction function to the 'Text' column of your DataFrame
df['Features'] = df['Text'].apply(extract_features)
df.head()
# Out:
#                                                 Text  Toxic/Not Toxic  \
# 0  يبغي التنبيه على ان السعودية تستخدم صواريخ جو ...                1
# 1  مريكا قتلت بالامس معوق رفض رفع يديه فماذا تريد...                1
# 2  هذا الشخص هو من كان يد لاحتلال العراق وضرب افغ...                1
# 3  الى جمال ريان مذيع الجزيرة نحن من رعاك فى المه...                1
# 4  خيبة ال مل ليست تشا ما ولا تقولا عزم لكفالة ال...                0
#
#                                               Vector  \
# 0  [-0.3958601, 0.15599905, 0.1723183, -0.8087594...
# 1  [-0.36112776, 0.30494243, 0.24558525, -0.47352...
# 2  [-0.46898466, 0.35995755, 0.46220547, -0.52535...
# 3  [-0.3926542, 0.20784305, 0.20726022, -0.409501...
# 4  [-0.36352453, 0.53330976, 0.3622666, -0.315772...
#
#                                             Features
# 0  [-0.44095376, 0.4403092, 0.16838475, -0.674998...
# 1  [-0.13516936, 0.60581374, 0.07339751, -0.46233...
# 2  [-0.34411076, 0.10868358, 0.0022517145, -0.353...
# 3  [-0.11144646, -0.17460942, 0.22897823, -1.0755...
# 4  [-0.96116817, 0.07800283, 0.17574903, -0.87016...

# %% [markdown]
# <h1> Partition

# %%
X_trainT, X_testT, y_trainT, y_testT = train_test_split(df['Features'].tolist(), df['Toxic/Not Toxic'].tolist(), test_size=0.2, random_state=42)

# %% [markdown]
# <h1>SVM

# %%
svm_modelT = SVC(verbose=1)
svm_modelT.fit(X_trainT, y_trainT)

y_predT = svm_modelT.predict(X_testT)

svm_scoresT = svm_modelT.decision_function(X_testT)
# Out:
# [LibSVM]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracyT = accuracy_score(y_testT, y_predT)
precisionT = precision_score(y_testT, y_predT)
recallT = recall_score(y_testT, y_predT)
f1T = f1_score(y_testT, y_predT)

print("Accuracy:", accuracyT)
print("Precision:", precisionT)
print("Recall:", recallT)
print("F1 Score:", f1T)
print(f1T)
# Out:
# Accuracy: 0.81782845296709
# Precision: 0.8186061658706035
# Recall: 0.86857866850956
# F1 Score: 0.8428523527439366
# 0.8428523527439366

# %%
import joblib

# Enregistrement du modèle
joblib.dump(svm_model, 'svc_yass_model.pkl')
# Out:
# ['svc_yass_model.pkl']

# %% [markdown]
# <h1> Random Forest

# %%
# Random Forest
rf = RandomForestClassifier()
rf.fit(X_trainT, y_trainT)
# Out:
# RandomForestClassifier()

# %%
rf_predTT_prob = rf.predict_proba(X_testT)[:,1]

y_predTT = rf.predict(X_testT)

# %%
# Calculate evaluation metrics
accuracyTT = accuracy_score(y_testT, y_predTT)
precisionTT = precision_score(y_testT, y_predTT)
recallTT = recall_score(y_testT, y_predTT)
f1TT = f1_score(y_testT, y_predTT)

print("Accuracy:", accuracyTT)
print("Precision:", precisionTT)
print("Recall:", recallTT)
print("F1 Score:", f1TT)
# Out:
# Accuracy: 0.7933402435864213
# Precision: 0.8053146542139203
# Recall: 0.8342547800046073
# F1 Score: 0.8195293052726862

# %% [markdown]
# <h1>Naive Bayes

# %%
# Naive Bayes
nb = GaussianNB()
nb.fit(X_trainT, y_trainT)
nb_pred_prob = nb.predict_proba(X_testT)[:,1]

# %%
y_predTTT = nb.predict(X_testT)

# %%
# Calculate evaluation metrics
accuracyTTT = accuracy_score(y_testT, y_predTTT)
precisionTTT = precision_score(y_testT, y_predTTT)
recallTTT = recall_score(y_testT, y_predTTT)
f1TTT = f1_score(y_testT, y_predTTT)

print("Accuracy:", accuracyTTT)
print("Precision:", precisionTTT)
print("Recall:", recallTTT)
print("F1 Score:", f1TTT)
# Out:
# Accuracy: 0.6929904120238404
# Precision: 0.7457922952250343
# Recall: 0.6890117484450587
# F1 Score: 0.7162785128420044

# %% [markdown]
# <h1> graph

# %%
# Compute the False Positive Rate (fpr) and True Positive Rate (tpr) for each classifier
fpr_rf, tpr_rf, _ = roc_curve(y_testT,  rf_predTT_prob)
fpr_svm, tpr_svm, _ = roc_curve(y_testT, svm_scoresT)
fpr_nb, tpr_nb, _ = roc_curve(y_testT, nb_pred_prob)  # Add Naive Bayes fpr and tpr



# Compute the Area Under Curve (AUC) for each classifier
roc_auc_rf = auc(fpr_rf, tpr_rf)
roc_auc_svm = auc(fpr_svm, tpr_svm)
roc_auc_nb = auc(fpr_nb, tpr_nb)  # Calculate Naive Bayes AUC

# Plot the ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_rf, tpr_rf, color='b', label=f'Random Forest + AB (AUC = {roc_auc_rf:.2f})')
plt.plot(fpr_svm, tpr_svm, color='g', label=f'SVM + AB (AUC = {roc_auc_svm:.2f})')
plt.plot(fpr_nb, tpr_nb, color='orange', label=f'Naive Bayes + AB (AUC = {roc_auc_nb:.2f})')  # Add Naive Bayes to the plot
plt.plot([0, 1], [0, 1], color='r', linestyle='--', label='Random')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
import torch
import pandas as pd

def extract_features(text):
    tokenizer = AutoTokenizer.from_pretrained('aubmindlab/bert-base-arabertv02')
    model = AutoModel.from_pretrained('aubmindlab/bert-base-arabertv02')
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    outputs = model(**inputs)
    sentence_representation = torch.mean(outputs.last_hidden_state[0], dim=0)
    return sentence_representation.detach().numpy()


Text1 = "متعجرف"

# Appliquez la fonction extract_features directement sur le texte
Vector1 = extract_features(Text1)
Vector1 = Vector1.reshape(1, -1)

# Effectuez les prédictions à l'aide des modèles entraînés précédemment (rf, svm_model, nb)
y3_preds = svm_modelT.predict(Vector1)
print(y3_preds)

#y1_predf = rf.predict(Vector1)

#y4_pred = nb.predict(Vector1)

# Affichez les prédictions
#print(y1_predf)

#print(y4_pred)
# Out:
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv02 were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [1]

# %%
import pickle

with open('svm_scores.pkl', 'rb') as f:
     svm_scores = pickle.load(f)
        
with open('rf_probs.pkl', 'rb') as f:
    rf_probs = pickle.load(f)

with open('nb_probs.pkl', 'rb') as f:
    nb_probs = pickle.load(f)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming you have the values for the different probabilities and y_test

# Compute the False Positive Rate (fpr) and True Positive Rate (tpr) for each classifier
fpr_rf_tfidf, tpr_rf_tfidf, _ = roc_curve(y_test, rf_probs)
fpr_svm_tfidf, tpr_svm_tfidf, _ = roc_curve(y_test, svm_scores)
fpr_nb_tfidf, tpr_nb_tfidf, _ = roc_curve(y_test, nb_probs)



fpr_rf_w2v, tpr_rf_w2v, _ = roc_curve(y_test, rf_pred_prob)
fpr_svm_w2v, tpr_svm_w2v, _ = roc_curve(y_test, svm_scores)
fpr_nb_w2v, tpr_nb_w2v, _ = roc_curve(y_test, nb_pred_prob)

fpr_rf_transformers, tpr_rf_transformers, _ = roc_curve(y_testT, rf_predTT_prob)
fpr_svm_transformers, tpr_svm_transformers, _ = roc_curve(y_testT, svm_scoresT)
fpr_nb_transformers, tpr_nb_transformers, _ = roc_curve(y_testT, nb_pred_prob)

# Compute the Area Under Curve (AUC) for each classifier
roc_auc_rf_tfidf = auc(fpr_rf_tfidf, tpr_rf_tfidf)
roc_auc_svm_tfidf = auc(fpr_svm_tfidf, tpr_svm_tfidf)
roc_auc_nb_tfidf = auc(fpr_nb_tfidf, tpr_nb_tfidf)

roc_auc_rf_w2v = auc(fpr_rf_w2v, tpr_rf_w2v)
roc_auc_svm_w2v = auc(fpr_svm_w2v, tpr_svm_w2v)
roc_auc_nb_w2v = auc(fpr_nb_w2v, tpr_nb_w2v)

roc_auc_rf_transformers = auc(fpr_rf_transformers, tpr_rf_transformers)
roc_auc_svm_transformers = auc(fpr_svm_transformers, tpr_svm_transformers)
roc_auc_nb_transformers = auc(fpr_nb_transformers, tpr_nb_transformers)

# Plot the ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_rf_tfidf, tpr_rf_tfidf, color='b', label=f'Random Forest + TF-IDF (AUC = {roc_auc_rf_tfidf:.2f})')
plt.plot(fpr_svm_tfidf, tpr_svm_tfidf, color='g', label=f'SVM + TF-IDF (AUC = {roc_auc_svm_tfidf:.2f})')
plt.plot(fpr_nb_tfidf, tpr_nb_tfidf, color='r', label=f'Gaussian Naive Bayes + TF-IDF (AUC = {roc_auc_nb_tfidf:.2f})')

plt.plot(fpr_rf_w2v, tpr_rf_w2v, color='c', label=f'Random Forest + Word2Vec (AUC = {roc_auc_rf_w2v:.2f})')
plt.plot(fpr_svm_w2v, tpr_svm_w2v, color='m', label=f'SVM + Word2Vec (AUC = {roc_auc_svm_w2v:.2f})')
plt.plot(fpr_nb_w2v, tpr_nb_w2v, color='y', label=f'Gaussian Naive Bayes + Word2Vec (AUC = {roc_auc_nb_w2v:.2f})')

plt.plot(fpr_rf_transformers, tpr_rf_transformers, color='k', label=f'Random Forest + Transformers (AUC = {roc_auc_rf_transformers:.2f})')
plt.plot(fpr_svm_transformers, tpr_svm_transformers, color='purple', label=f'SVM + Transformers (AUC = {roc_auc_svm_transformers:.2f})')
plt.plot(fpr_nb_transformers, tpr_nb_transformers, color='orange', label=f'Gaussian Naive Bayes + Transformers (AUC = {roc_auc_nb_transformers:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Random')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
